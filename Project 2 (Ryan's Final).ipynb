# %% [markdown]
# # Project 2
# ## Step 1: Exploring your data.
#
# ##### Load your data in using Pandas and start to explore. Save all of your early exploration code here and include in your final submission.

# %%
import pandas as pd
import numpy as np

# %%
file_name = ('/Users/ryangin/Desktop/General_Assembly/DSI_SM_01/curriculum/week-02/2.4-lab/assets/datasets/billboard.csv')

# %%
df = pd.read_csv(file_name) # Reads the file into python and create a dataframe (df)
df
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
df.describe() # Describes the dataframe (count, mean, std, min, 25%, 50%, 75%, max)
# Out:
#          year   x1st.week   x2nd.week   x3rd.week   x4th.week   x5th.week  \
# count   317.0  317.000000  312.000000  307.000000  300.000000  292.000000
# mean   2000.0   79.958991   71.173077   65.045603   59.763333   56.339041
# std       0.0   14.686865   18.200443   20.752302   22.324619   23.780022
# min    2000.0   15.000000    8.000000    6.000000    5.000000    2.000000
# 25%    2000.0   74.000000   63.000000   53.000000   44.750000   38.750000
# 50%    2000.0   81.000000   73.000000   66.000000   61.000000   57.000000
# 75%    2000.0   91.000000   84.000000   79.000000   76.000000   73.250000
# max    2000.0  100.000000  100.000000  100.000000  100.000000  100.000000
#
#         x6th.week   x7th.week   x8th.week   x9th.week     ...      x67th.week  \
# count  280.000000  269.000000  260.000000  253.000000     ...             0.0
# mean    52.360714   49.219331   47.119231   46.343874     ...             NaN
# ...

# %%
df.apply(np.sum, axis = 0).tail(25) # Shows week 66-76 (x66th.week to x76th.week) have NaN values in entire columns
# Out:
# x52nd.week    121
# x53rd.week    133
# x54th.week     39
# x55th.week     43
# x56th.week     51
# x57th.week     55
# x58th.week     63
# x59th.week     71
# x60th.week     76
# x61st.week     85
# x62nd.week     89
# x63rd.week     95
# x64th.week    100
# x65th.week     49
# x66th.week    NaN
# x67th.week    NaN
# x68th.week    NaN
# x69th.week    NaN
# x70th.week    NaN
# x71st.week    NaN
# x72nd.week    NaN
# x73rd.week    NaN
# x74th.week    NaN
# x75th.week    NaN
# x76th.week    NaN
# dtype: object

# %%
df.shape # Gives the complete number of rows (317) and columns (83)
# Out:
# (317, 83)

# %%
df.columns # diplays all columns in dataframe
# Out:
# Index([u'year', u'artist.inverted', u'track', u'time', u'genre',
#        u'date.entered', u'date.peaked', u'x1st.week', u'x2nd.week',
#        u'x3rd.week', u'x4th.week', u'x5th.week', u'x6th.week', u'x7th.week',
#        u'x8th.week', u'x9th.week', u'x10th.week', u'x11th.week', u'x12th.week',
#        u'x13th.week', u'x14th.week', u'x15th.week', u'x16th.week',
#        u'x17th.week', u'x18th.week', u'x19th.week', u'x20th.week',
#        u'x21st.week', u'x22nd.week', u'x23rd.week', u'x24th.week',
#        u'x25th.week', u'x26th.week', u'x27th.week', u'x28th.week',
#        u'x29th.week', u'x30th.week', u'x31st.week', u'x32nd.week',
#        u'x33rd.week', u'x34th.week', u'x35th.week', u'x36th.week',
#        u'x37th.week', u'x38th.week', u'x39th.week', u'x40th.week',
#        u'x41st.week', u'x42nd.week', u'x43rd.week', u'x44th.week',
#        u'x45th.week', u'x46th.week', u'x47th.week', u'x48th.week',
#        u'x49th.week', u'x50th.week', u'x51st.week', u'x52nd.week',
# ...

# %%
df[['date.peaked','x1st.week']].head() # Displays the head (first 5) of date.peaked and the 1st week
# Out:
#   date.peaked  x1st.week
# 0  2000-11-18         78
# 1  2000-04-08         15
# 2  2000-01-29         71
# 3  2000-09-16         41
# 4  2000-10-14         57

# %%
df[['date.peaked','x1st.week']].tail() # Displays the tail (last 5) of date.peaked and the 1st week
# Out:
#     date.peaked  x1st.week
# 312  2000-08-05       98.0
# 313  2000-02-12       99.0
# 314  2000-09-02       99.0
# 315  2000-07-01       99.0
# 316  2000-10-28       99.0

# %% [markdown]
# ##### Write a brief description of your data, and any interesting observations you've made thus far.

# %% [markdown]
# This data is looking at different hit songs from the Billboard charts from the '00s and seeing when they reached the top of the charts and how long it stayed there. The data represented shows the number of weeks from 1-76 from when the song was first entered. The rank is represented in each week for each song. The peak time, or when the song reached number 1 on the billboard charts, is also indicated in the column peak date. There are empty cells from weeks 25-27. From weeks 66-76, all the songs contain NaN values.

# %% [markdown]
# ## Step 2: Clean your data.

# %% [markdown]
# ##### Do some rudimentary cleaning. Rename any columns that are poorly named, shorten any strings that may be too long, fill in any missing values. Explain your rationale for the way you choose to "impute" the missing data.

# %%
df1 = df.dtypes # Displays the all the types of all the columns in the dataset
df1
# Out:
# year                 int64
# artist.inverted     object
# track               object
# time                object
# genre               object
# date.entered        object
# date.peaked         object
# x1st.week            int64
# x2nd.week          float64
# x3rd.week          float64
# x4th.week          float64
# x5th.week          float64
# x6th.week          float64
# x7th.week          float64
# x8th.week          float64
# x9th.week          float64
# x10th.week         float64
# x11th.week         float64
# x12th.week         float64
# x13th.week         float64
# x14th.week         float64
# x15th.week         float64
# x16th.week         float64
# x17th.week         float64
# x18th.week         float64
# x19th.week         float64
# x20th.week         float64
# x21st.week         float64
# x22nd.week         float64
# x23rd.week         float64
#                     ...
# x47th.week         float64
# x48th.week         float64
# x49th.week         float64
# ...

# %%
df2 = df[['x1st.week']] = df[['x1st.week']].astype(float) # converts the 'x1st.week' column 
# from a int to a float
df2.dtypes
# Out:
# x1st.week    float64
# dtype: object

# %%
pd.pivot_table(df, index = ['artist.inverted', 'track', 'genre'], values = ['x1st.week']).sort()
# Create pivot table
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   if __name__ == '__main__':
#                                                                                      x1st.week
# artist.inverted      track                                              genre
# 2 Pac                Baby Don't Cry (Keep Ya Head Up II)                Rap               87.0
# 2Ge+her              The Hardest Part Of Breaking Up (Is Getting Bac... R&B               91.0
# 3 Doors Down         Kryptonite                                         Rock              81.0
#                      Loser                                              Rock              76.0
# 504 Boyz             Wobble Wobble                                      Rap               57.0
# 98�                  Give Me Just One Night (Una Noche)                 Rock              51.0
# ...

# %%
dfWeeksOnBillboard = df.notnull().sum(axis = 1)
dfWeeksOnBillboard
# Out:
# 0      35
# 1      33
# 2      40
# 3      31
# 4      28
# 5      31
# 6      39
# 7      27
# 8      33
# 9      62
# 10     32
# 11     31
# 12     48
# 13     54
# 14     39
# 15     46
# 16     27
# 17     60
# 18     37
# 19     35
# 20     44
# 21     39
# 22     27
# 23     39
# 24     60
# 25     35
# 26     29
# 27     35
# 28     51
# 29     39
#        ..
# 287    10
# 288    27
# 289    12
# 290    25
# 291    10
# 292    16
# 293    13
# 294    12
# 295    19
# 296    13
# 297    14
# 298    11
# 299    11
# 300    15
# 301    10
# 302    11
# 303    14
# 304    12
# 305    12
# 306    10
# 307    10
# 308    10
# 309     9
# 310     9
# 311     8
# 312     8
# 313    11
# 314     9
# 315     9
# 316     8
# dtype: int64

# %%
remove_na = df.dropna(axis=1, how = 'all') # Drops the columns that contain all 
# NaN values (weeks 66-76)
remove_na
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
remove_na.count() # Counts the number of values in columns, NaN values don't show up
# Out:
# year               317
# artist.inverted    317
# track              317
# time               317
# genre              317
# date.entered       317
# date.peaked        317
# x1st.week          317
# x2nd.week          312
# x3rd.week          307
# x4th.week          300
# x5th.week          292
# x6th.week          280
# x7th.week          269
# x8th.week          260
# x9th.week          253
# x10th.week         244
# x11th.week         236
# x12th.week         222
# x13th.week         210
# x14th.week         204
# x15th.week         197
# x16th.week         182
# x17th.week         177
# x18th.week         166
# x19th.week         156
# x20th.week         146
# x21st.week          65
# x22nd.week          55
# x23rd.week          48
#                   ...
# x36th.week           9
# x37th.week           9
# x38th.week           8
# x39th.week           8
# x40th.week           7
# x41st.week           7
# x42nd.week           6
# x43rd.week           6
# x44th.week           6
# ...

# %%
column_names = remove_na.columns.tolist()
column_names[column_names.index('year')] = 'Year'
column_names[column_names.index('artist.inverted')] = 'Artist'
column_names[column_names.index('track')] = 'Track'
column_names[column_names.index('time')] = 'Time'
column_names[column_names.index('genre')] = 'Genre'
column_names[column_names.index('date.entered')] = 'Date Entered'
column_names[column_names.index('date.peaked')] = 'Date Peaked'

for i in column_names:
  y = i  
  if str(i).startswith('x'):
      i = i[1: ]
      #print(i)
      i = str(i).replace('.', ' ')
      #print(i)
      column_names[column_names.index ( y) ] = i
      remove_na.columns = column_names
print (column_names)
# Out:
# ['Year', 'Artist', 'Track', 'Time', 'Genre', 'Date Entered', 'Date Peaked', '1st week', '2nd week', '3rd week', '4th week', '5th week', '6th week', '7th week', '8th week', '9th week', '10th week', '11th week', '12th week', '13th week', '14th week', '15th week', '16th week', '17th week', '18th week', '19th week', '20th week', '21st week', '22nd week', '23rd week', '24th week', '25th week', '26th week', '27th week', '28th week', '29th week', '30th week', '31st week', '32nd week', '33rd week', '34th week', '35th week', '36th week', '37th week', '38th week', '39th week', '40th week', '41st week', '42nd week', '43rd week', '44th week', '45th week', '46th week', '47th week', '48th week', '49th week', '50th week', '51st week', '52nd week', '53rd week', '54th week', '55th week', '56th week', '57th week', '58th week', '59th week', '60th week', '61st week', '62nd week', '63rd week', '64th week', '65th week']

# %%
piv_tab = pd.pivot_table(remove_na, index = ('Artist', 'Track'))
piv_tab
# Out:
#                                                                          10th week  \
# Artist               Track
# 2 Pac                Baby Don't Cry (Keep Ya Head Up II)                       NaN
# 2Ge+her              The Hardest Part Of Breaking Up (Is Getting Bac...        NaN
# 3 Doors Down         Kryptonite                                               51.0
#                      Loser                                                    61.0
# 504 Boyz             Wobble Wobble                                            57.0
# 98�                  Give Me Just One Night (Una Noche)                        6.0
# A*Teens              Dancing Queen                                             NaN
# Aaliyah              I Don't Wanna                                            36.0
#                      Try Again                                                10.0
# Adams, Yolanda       Open My Heart                                            59.0
# ...

# %%
# find out the number of weeks each song has been on the billboard
dfWeeksOnBillboard1 = piv_tab.notnull().sum(axis = 1)
dfWeeksOnBillboard1
# Out:
# Artist                Track
# 2 Pac                 Baby Don't Cry (Keep Ya Head Up II)                              8
# 2Ge+her               The Hardest Part Of Breaking Up (Is Getting Back Your Stuff)     4
# 3 Doors Down          Kryptonite                                                      54
#                       Loser                                                           21
# 504 Boyz              Wobble Wobble                                                   19
# 98�                   Give Me Just One Night (Una Noche)                              21
# A*Teens               Dancing Queen                                                    6
# Aaliyah               I Don't Wanna                                                   21
#                       Try Again                                                       33
# Adams, Yolanda        Open My Heart                                                   21
# ...

# %% [markdown]
# ##### Using Pandas' built in `melt` function, pivot the weekly ranking data to be long rather than wide. As a result, you will have removed the 72 'week' columns and replace it with two: Week and Ranking. There will now be multiple entries for each song, one for each week on the Billboard rankings.

# %%
melted = pd.melt(piv_tab.reset_index(), id_vars=['Artist', 'Track'],
            var_name='col', value_name='val')
melted
# Out:
#                      Artist  \
# 0                     2 Pac
# 1                   2Ge+her
# 2              3 Doors Down
# 3              3 Doors Down
# 4                  504 Boyz
# 5                       98�
# 6                   A*Teens
# 7                   Aaliyah
# 8                   Aaliyah
# 9            Adams, Yolanda
# 10            Adkins, Trace
# 11      Aguilera, Christina
# 12      Aguilera, Christina
# 13      Aguilera, Christina
# 14             Alice Deejay
# 15              Allan, Gary
# 16                    Amber
# 17                Anastacia
# 18            Anthony, Marc
# 19            Anthony, Marc
# 20                    Avant
# 21                    Avant
# 22                    BBMak
# 23     Backstreet Boys, The
# 24     Backstreet Boys, The
# 25     Backstreet Boys, The
# 26             Badu, Erkyah
# 27                 Baha Men
# 28         Barenaked Ladies
# 29               Beenie Man
# ...                     ...
# 20892          Thomas, Carl
# ...

# %%
billboard_top = melted[melted.val == 1].sort_values(by='Artist')
billboard_top
# Out:
#                     Artist                                  Track        col  \
# 1276               Aaliyah                              Try Again  14th week
# 328    Aguilera, Christina  Come On Over Baby (All I Want Is You)  11th week
# 20301  Aguilera, Christina                      What A Girl Wants   9th week
# 19984  Aguilera, Christina                      What A Girl Wants   8th week
# 645    Aguilera, Christina  Come On Over Baby (All I Want Is You)  12th week
# 1279   Aguilera, Christina  Come On Over Baby (All I Want Is You)  14th week
# 962    Aguilera, Christina  Come On Over Baby (All I Want Is You)  13th week
# 369          Carey, Mariah                  Thank God I Found You  11th week
# 5769                 Creed                    With Arms Wide Open  27th week
# 1342       Destiny's Child               Independent Women Part I  14th week
# 1344       Destiny's Child                            Say My Name  14th week
# ...

# %%
top_songs = billboard_top['Track'].value_counts()
top_songs
# Out:
# Independent Women Part I                 11
# Maria, Maria                             10
# I Knew I Loved You                        4
# Music                                     4
# Come On Over Baby (All I Want Is You)     4
# Be With You                               3
# Doesn't Really Matter                     3
# Say My Name                               3
# What A Girl Wants                         2
# Incomplete                                2
# Amazed                                    2
# It's Gonna Be Me                          2
# Bent                                      1
# Everything You Want                       1
# Thank God I Found You                     1
# With Arms Wide Open                       1
# Try Again                                 1
# Name: Track, dtype: int64

# %%
billboard_top10 = melted[melted.val <= 10].sort_values(by='Artist')
billboard_top10
# Out:
#                  Artist                               Track        col   val
# 5391       3 Doors Down                          Kryptonite  26th week   5.0
# 5708       3 Doors Down                          Kryptonite  27th week   5.0
# 6025       3 Doors Down                          Kryptonite  28th week   4.0
# 6342       3 Doors Down                          Kryptonite  29th week   4.0
# 6976       3 Doors Down                          Kryptonite  30th week   4.0
# 7293       3 Doors Down                          Kryptonite  31st week   4.0
# 7610       3 Doors Down                          Kryptonite  32nd week   3.0
# 7927       3 Doors Down                          Kryptonite  33rd week   3.0
# 4757       3 Doors Down                          Kryptonite  24th week   6.0
# 8244       3 Doors Down                          Kryptonite  34th week   3.0
# 8878       3 Doors Down                          Kryptonite  36th week   5.0
# ...

# %%
top10_songs = billboard_top10['Track'].value_counts()
top10_songs
# Out:
# Breathe                                  19
# Everything You Want                      19
# With Arms Wide Open                      18
# Maria, Maria                             18
# Kryptonite                               18
# Independent Women Part I                 17
# My Love Is Your Love                     17
# I Knew I Loved You                       17
# Jumpin' Jumpin'                          16
# I Wanna Know                             16
# Try Again                                15
# Bent                                     14
# Case Of The Ex (Whatcha Gonna Do)        13
# Thong Song                               13
# Incomplete                               13
# Bye Bye Bye                              12
# Amazed                                   12
# Doesn't Really Matter                    12
# Music                                    12
# Get It On.. Tonite                       12
# Say My Name                              11
# ...

# %% [markdown]
# ## Step 3: Visualize your data.

# %% [markdown]
# ##### Using a plotting utility of your choice (Tableau or python modules or both), create visualizations that will provide context to your data. There is no minimum or maximum number of graphs you should generate, but there should be a clear and consistent story being told. Give insights to the distribution, statistics, and relationships of the data.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
sns.countplot(y='Track', data=billboard_top)
plt.title('Number 1 Songs in the Year 2000')
plt.xlabel('Frequency')
plt.ylabel('Track')

for p in ax.patches:
        ax.annotate('%{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))

# %%
plt.figure(figsize=(10,30))
sns.countplot(y='Track', data=billboard_top10)
plt.title('Songs in the Top 10')
plt.xlabel('Frequency')
plt.ylabel('Track')

for p in ax.patches:
        ax.annotate('%{:.1f}'.format(p.get_height()), (p.get_x()+0.1, p.get_height()+50))

# %% [markdown]
# ## Step 4: Create a Problem Statement.
#
# ##### Having explored the data, come up with a problem statement for this data set. You can feel free to introduce data from any other source to support your problem statement, just be sure to provide a link to the origin of the data. Once again- be creative!

# %% [markdown]
# What songs in the year 2000 made it to number 1 or were in the top 10 on the billboard charts and for how many times?

# %% [markdown]
# ## Step 5: Brainstorm your Approach.
# ##### In bullet-list form, provide a proposed approach for evaluating your problem statement. This can be somewhat high-level, but start to think about ways you can massage the data for maximum efficacy.

# %% [markdown]
# My Approach
#
# - First, I read in the data using pandas csv reader
# - Did some exploratory analysis of the data using the head, tail, describe functions and
# - I also used the apply function on the tail of the data set by summing each column in the dataset, which showed me that the last set of columns contained all NaNs in them b/c their sums came out to NaN
# - I used the shape and columns functions as well to examine the shape of the dataset and to see all the columns in the dataset
# - To clean the dataset, I first changed the x1st.week column from an int64 to a float64 to match the other weeks
# - I used the notnull() function to see how many weeks a particular song was on the billboard charts and then I used the dropna() function to remove all the columns that contained only NaN values
# - I renamed all the columns and removed anything that I felt was inappropriate
# - I created a pivot table by artist and track and once again showed the number of times that each song was on the billboard charts using the notnull() function
# - From there, I used the melt function, to group the Artist and track and melt everything else into 2 columns called 'col' and 'val'.
# - Using the 'val' column and the table I created called 'melted' I could then find the number of times a particular song was number 1 or in the top 10.
# - After this, I used seaborn to create plots that showed the songs that were number 1 and how many times and also the songs that were in the top 10 and their frequency as well.

# %% [markdown]
# ## Step 6: Create a blog post with your code snippets and visualizations.
# ##### Data Science is a growing field, and the Tech industry thrives off of collaboration and sharing of knowledge. Blogging is a powerful means for pushing the needle forward in our field. Using your blogging platform of choice, create a post describing each of the 5 steps above. Rather than writing a procedural text, imagine you're describing the data, visualizations, and conclusions you've arrived at to your peers. Aim for a minimum of 500 words.

# %% [markdown]
# The dataset that we were looking at examined different hit songs from the Billboard charts from the '00s and indicated their performance, when they peaked and how long they stayed that way for a 76 week period. While interesting, this dataset was not without errors.
#
# In order to clean the dataset, the two things I thought were most beneficial were removing the columns that contained only NaNs in them and also renaming the columns as well.
#
# Code Snippet to Remove NaN Columns:
# remove_na = df.dropna(axis=1, how = 'all')
# remove_na
#
# Code Snippet to Rename Columns:
# column_names = remove_na.columns.tolist()
# column_names[column_names.index('year')] = 'Year'
# column_names[column_names.index('artist.inverted')] = 'Artist'
# column_names[column_names.index('track')] = 'Track'
# column_names[column_names.index('time')] = 'Time'
# column_names[column_names.index('genre')] = 'Genre'
# column_names[column_names.index('date.entered')] = 'Date Entered'
# column_names[column_names.index('date.peaked')] = 'Date Peaked'
#
# for i in column_names:
#   y = i
#   if str(i).startswith('x'):
#       i = i[1: ]
#       #print(i)
#       i = str(i).replace('.', ' ')
#       #print(i)
#       column_names[column_names.index ( y) ] = i
#       remove_na.columns = column_names
# print (column_names)
#
#
# Other than that, the dataset seemed relatively clean and easy to work with. I opted to not fill the remaining NaN values because I used them to find out how many times each song was on the billboard charts.
#
# Code Snippet to find out Weeks on Billboard per track:
#
# dfWeeksOnBillboard1 = piv_tab.notnull().sum(axis = 1)
# dfWeeksOnBillboard1
#
# My ultimate goal, however, was to determine the number one songs in this dataset and how many times they stayed that way. In order to do that, I had to manipulate the data somewhat by creating a pivot table of the Artist and Track and then the melt function to stack all the weeks and their values on top of each other by Artist and Track.
#
# Code Snippet for Melt Function:
#
# melted = pd.melt(piv_tab.reset_index(), id_vars=['Artist', 'Track'],
#             var_name='col', value_name='val')
# melted
#
#
# By doing this, I could determine all the songs that were in a particular rank whether the number 1 or top 10, etc. I opted to display these two categories because I felt that they would be most relevant for anyone looking at this dataset. As you can see, "Indpendent Woman Part 1" by Destiny's Child and "Maria, Maria" by Santana were number one the most frequent times with 11 and 10 times respectively. "Breathe" by Faith Hill and "Everything You Want" by Vertical Horizon were most often in the top 10 with 19 times each.

# %% [markdown]
# ## BONUS: The Content Managers working for the Podcast Publishing Company have recognized you as a thought leader in your field. They've asked you to pen a white paper (minimum 500 words) on the subject of 'What It Means To Have Clean Data'. This will be an opinion piece read by a wide audience, so be sure to back up your statements with real world examples or scenarios.
#
# ##### Hint: To get started, look around on the internet for articles, blog posts, papers, youtube videos, podcasts, reddit discussions, anything that will help you understand the challenges and implications of dealing with big data. This should be a personal reflection on everything you've learned this week, and the learning goals that have been set out for you going forward.
