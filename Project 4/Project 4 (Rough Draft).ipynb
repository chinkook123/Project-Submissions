# %% [markdown]
# # Web Scraping for Indeed.com & Predicting Salaries

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com. In the second, we'll focus on using listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# #### Complete the following code to collect results from multiple cities and starting points.
# - Enter your city below to add it to the search
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %% [markdown]
# Lastly, we need to clean up salary data.
# 1. Some of the salaries are not yearly but hourly, these will be useful to us for now
# 2. The salaries are given as text and usually with ranges.
#
# #### Filter out the salaries that are not yearly (filter those that refer to hour)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %% [markdown]
# ### Save your results as a CSV

# %%
## YOUR CODE HERE

# %% [markdown]
# ## Predicting salaries using Logistic Regression

# %% [markdown]
# #### Load in the the data of scraped salaries

# %%
BASE_URL = "/Users/ryangin/Desktop/General_Assembly/DSI_SM_01/projects/01-projects-weekly/project-04/assets/indeed-scraped-job-postings.csv"

# %%
## YOUR CODE HERE
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import seaborn as sns
import datetime as dt

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

plt.style.use('seaborn-white')

# %%
## YOUR CODE HERE
df = pd.read_csv(BASE_URL)
df.head()
# Out:
#             city                  company                      salary  \
# 0  San+Francisco              MarkMonitor             $180,000 a year
# 1  San+Francisco    Workbridge Associates  $130,000 - $180,000 a year
# 2  San+Francisco                 Mines.io   $80,000 - $120,000 a year
# 3  San+Francisco    Workbridge Associates  $150,000 - $180,000 a year
# 4  San+Francisco  Smith Hanley Associates             $140,000 a year
#
#                                              summary  \
# 0  Data skills (SQL, Hive, Pig). Applying machine...
# 1  3+ years of industry experience in a data scie...
# 2  We are looking for a data scientist/developer ...
# 3  In this position you will share programming an...
# 4  This person will recruit, build and lead a tea...
#
#                        title  parsed_salary
# 0             Data Scientist       180000.0
# 1      Senior Data Scientist       155000.0
# 2  Full-Stack Data Scientist       100000.0
# 3             Data Scientist       165000.0
# 4             Data Scientist       140000.0

# %%
df.dtypes
# Out:
# city              object
# company           object
# salary            object
# summary           object
# title             object
# parsed_salary    float64
# dtype: object

# %%
df.shape
# Out:
# (4791, 6)

# %%
df.describe()
# Out:
#        parsed_salary
# count    4789.000000
# mean    66183.785550
# std     64348.141986
# min      2333.000000
# 25%      5950.000000
# 50%     74550.000000
# 75%    130000.000000
# max    300000.000000

# %%
Top_Salary = df.sort_values(by = 'parsed_salary', ascending = False)
Top_Salary.head(10)
# Out:
#               city                   company                      salary  \
# 5    San+Francisco            HSF Consulting             $300,000 a year
# 13   San+Francisco            HSF Consulting             $300,000 a year
# 427       New+York                   Averity  $200,000 - $300,000 a year
# 25   San+Francisco        Jobspring Partners  $180,000 - $275,000 a year
# 42   San+Francisco        Jobspring Partners  $180,000 - $275,000 a year
# 442       New+York                   Averity  $175,000 - $275,000 a year
# 432       New+York   Oliver James Associates  $180,000 - $250,000 a year
# 425       New+York   Oliver James Associates  $180,000 - $250,000 a year
# 447       New+York                NJF Search             $200,000 a year
# 414       New+York  Datacom Technology Group             $200,000 a year
#
#                                                summary  \
# 5    Teams included Data Services(including data en...
# 13   Teams included Data Services(including data en...
# 427  ContactMichael Pachella (michael.pachella@aver...
# 25   This is an opportunity to lead a team of talen...
# 42   This is an opportunity to lead a team of talen...
# 442  We are a top-tier asset manager looking for a ...
# 432  This is an excellent opportunity for a candida...
# 425  This is an excellent opportunity for a candida...
# 447  Demonstrated ability to conduct independent re...
# 414  Should have experience conducting empirical re...
#
#                                                  title  parsed_salary
# 5                                  VP of Data Services       300000.0
# 13                                 VP of Data Services       300000.0
# 427  Quantitative Analyst (Big Data Focus) at $10+ ...       250000.0
# 25   Vice President Engineering (Big Data/ Machine ...       227500.0
# 42   Vice President Engineering (Big Data/ Machine ...       227500.0
# 442  Quantitative Data Scientist - Large Asset Manager       225000.0
# 432                   VP - Predictive Modeling Actuary       215000.0
# 425                   VP - Predictive Modeling Actuary       215000.0
# 447    Machine Learning Research Scientist - Hedgefund       200000.0
# 414  Quantitative Analyst (Fundamental Quant Equiti...       200000.0

# %% [markdown]
# #### We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median)

# %%
## YOUR CODE HERE
median = Top_Salary['parsed_salary'].median()
median
# Out:
# 74550.0

# %%
## YOUR CODE HERE
mean = Top_Salary['parsed_salary'].mean()
mean
# Out:
# 66183.78555021925

# %%
Top_Salary.dropna(inplace=True)
#sac['price'] = sac[[x for x in column_names if x not in ['class','id']]].sum(axis=1)/90.
Top_Salary['binary_variable'] = Top_Salary['parsed_salary'].map(lambda x: 0 if x <=median else 1)

# %%
Top_Salary.head()
# Out:
#               city             company                      salary  \
# 5    San+Francisco      HSF Consulting             $300,000 a year
# 13   San+Francisco      HSF Consulting             $300,000 a year
# 427       New+York             Averity  $200,000 - $300,000 a year
# 25   San+Francisco  Jobspring Partners  $180,000 - $275,000 a year
# 42   San+Francisco  Jobspring Partners  $180,000 - $275,000 a year
#
#                                                summary  \
# 5    Teams included Data Services(including data en...
# 13   Teams included Data Services(including data en...
# 427  ContactMichael Pachella (michael.pachella@aver...
# 25   This is an opportunity to lead a team of talen...
# 42   This is an opportunity to lead a team of talen...
#
#                                                  title  parsed_salary  \
# 5                                  VP of Data Services       300000.0
# 13                                 VP of Data Services       300000.0
# 427  Quantitative Analyst (Big Data Focus) at $10+ ...       250000.0
# 25   Vice President Engineering (Big Data/ Machine ...       227500.0
# 42   Vice President Engineering (Big Data/ Machine ...       227500.0
#
#      binary_variable
# 5                  1
# 13                 1
# 427                1
# 25                 1
# 42                 1

# %%
Top_Salary.ix[:,0:]
# Out:
#                city                                  company  \
# 5     San+Francisco                           HSF Consulting
# 13    San+Francisco                           HSF Consulting
# 427        New+York                                  Averity
# 25    San+Francisco                       Jobspring Partners
# 42    San+Francisco                       Jobspring Partners
# 442        New+York                                  Averity
# 432        New+York                  Oliver James Associates
# 425        New+York                  Oliver James Associates
# 447        New+York                               NJF Search
# 414        New+York                 Datacom Technology Group
# 413        New+York                         Technical Source
# 496        New+York                      Hire Solutions Inc.
# 45    San+Francisco                                       LT
# 506        New+York                      Hire Solutions Inc.
# 436        New+York                                  Averity
# 3635        Chicago                               NJF Search
# 3550        Seattle                         All-In Analytics
# 3542        Seattle                         All-In Analytics
# 3528        Seattle                         All-In Analytics
# 3537        Seattle                         All-In Analytics
# 3632        Chicago                    Workbridge Associates
# 3641        Chicago                 Penfield Search Partners
# 3643        Chicago                 Penfield Search Partners
# 3646        Chicago                 Penfield Search Partners
# 501        New+York                      Analytic Recruiting
# 3640        Chicago                    Workbridge Associates
# 35    San+Francisco                    Workbridge Associates
# 47    San+Francisco                                       LT
# 0     San+Francisco                              MarkMonitor
# 440        New+York                           Selby Jennings
# ...             ...                                      ...
# 2240         Austin            University of Texas at Austin
# 2237         Austin            University of Texas at Austin
# 2233         Austin            University of Texas at Austin
# 2188         Austin            University of Texas at Austin
# 2232         Austin            University of Texas at Austin
# 2218         Austin            University of Texas at Austin
# 2214         Austin            University of Texas at Austin
# 2193         Austin            University of Texas at Austin
# 2195         Austin            University of Texas at Austin
# 2200         Austin            University of Texas at Austin
# 2202         Austin            University of Texas at Austin
# 2207         Austin            University of Texas at Austin
# 2210         Austin            University of Texas at Austin
# 2211         Austin            University of Texas at Austin
# 2608         Austin            University of Texas at Austin
# 2223         Austin            University of Texas at Austin
# 2226         Austin            University of Texas at Austin
# 3543        Seattle  University of Washington Medical Center
# 3549        Seattle  University of Washington Medical Center
# 3567        Seattle                 University of Washington
# 3552        Seattle  University of Washington Medical Center
# 3544        Seattle                 University of Washington
# 3548        Seattle  University of Washington Medical Center
# 3541        Seattle  University of Washington Medical Center
# 3566        Seattle                 University of Washington
# 3540        Seattle              Washington State Government
# 3539        Seattle              Washington State Government
# 46    San+Francisco                                Galvanize
# 867          Austin            University of Texas at Austin
# 873          Austin            University of Texas at Austin
#
#                           salary  \
# 5                $300,000 a year
# 13               $300,000 a year
# 427   $200,000 - $300,000 a year
# 25    $180,000 - $275,000 a year
# 42    $180,000 - $275,000 a year
# 442   $175,000 - $275,000 a year
# 432   $180,000 - $250,000 a year
# 425   $180,000 - $250,000 a year
# 447              $200,000 a year
# 414              $200,000 a year
# 413              $200,000 a year
# 496              $200,000 a year
# 45               $200,000 a year
# 506              $200,000 a year
# 436   $150,000 - $250,000 a year
# 3635             $200,000 a year
# 3550  $150,000 - $230,000 a year
# 3542  $150,000 - $230,000 a year
# 3528  $150,000 - $230,000 a year
# 3537  $150,000 - $230,000 a year
# 3632             $185,000 a year
# 3641             $185,000 a year
# 3643             $185,000 a year
# 3646             $185,000 a year
# 501              $185,000 a year
# 3640             $180,000 a year
# 35    $165,000 - $195,000 a year
# 47               $180,000 a year
# 0                $180,000 a year
# 440   $150,000 - $200,000 a year
# ...                          ...
# 2240              $3,210 a month
# 2237              $3,210 a month
# 2233              $3,210 a month
# 2188              $3,210 a month
# 2232              $3,210 a month
# 2218              $3,210 a month
# 2214              $3,210 a month
# 2193              $3,210 a month
# 2195              $3,210 a month
# 2200              $3,210 a month
# 2202              $3,210 a month
# 2207              $3,210 a month
# 2210              $3,210 a month
# 2211              $3,210 a month
# 2608              $3,210 a month
# 2223              $3,210 a month
# 2226              $3,210 a month
# 3543     $2,919 - $3,360 a month
# 3549     $2,919 - $3,360 a month
# 3567     $2,572 - $3,573 a month
# 3552     $2,572 - $3,573 a month
# 3544     $2,453 - $3,239 a month
# 3548     $2,453 - $3,239 a month
# 3541     $2,370 - $3,129 a month
# 3566     $2,370 - $3,129 a month
# 3540     $2,226 - $2,873 a month
# 3539     $2,226 - $2,873 a month
# 46                $2,500 a month
# 867               $2,333 a month
# 873               $2,333 a month
#
#                                                 summary  \
# 5     Teams included Data Services(including data en...
# 13    Teams included Data Services(including data en...
# 427   ContactMichael Pachella (michael.pachella@aver...
# 25    This is an opportunity to lead a team of talen...
# 42    This is an opportunity to lead a team of talen...
# 442   We are a top-tier asset manager looking for a ...
# 432   This is an excellent opportunity for a candida...
# 425   This is an excellent opportunity for a candida...
# 447   Demonstrated ability to conduct independent re...
# 414   Should have experience conducting empirical re...
# 413   Data analytics and modeling, data visualizatio...
# 496   We are looking for data scientist, NLP special...
# 45    We have four QA engineers with three more open...
# 506   We are looking for data scientist, NLP special...
# 436   Knowledge big data analysis and systems. Indiv...
# 3635  Looking for a Research Scientist with a backgr...
# 3550  Searching for a top notch business scientist t...
# 3542  Senior Business Intelligence Data Scientist. O...
# 3528  Digital Data Scientist. Big Data Mining and An...
# 3537  Senior Business Intelligence Data Scientist. O...
# 3632  They need someone with the experience to be ha...
# 3641  Oversee or partner in development of data qual...
# 3643  Oversee or partner in development of data qual...
# 3646  Oversee or partner in development of data qual...
# 501   Work with data engineers, data scientists and ...
# 3640  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 35    The role will be working on technology that pr...
# 47    We have two QA engineers with three more open ...
# 0     Data skills (SQL, Hive, Pig). Applying machine...
# 440   VP Data Scientist. A top investment bank in Ne...
# ...                                                 ...
# 2240  Ability to interpret CT data as applicable to ...
# 2237  Ability to interpret CT data as applicable to ...
# 2233  Ability to interpret CT data as applicable to ...
# 2188  Ability to interpret CT data as applicable to ...
# 2232  Ability to interpret CT data as applicable to ...
# 2218  Ability to interpret CT data as applicable to ...
# 2214  Ability to interpret CT data as applicable to ...
# 2193  Ability to interpret CT data as applicable to ...
# 2195  Ability to interpret CT data as applicable to ...
# 2200  Ability to interpret CT data as applicable to ...
# 2202  Ability to interpret CT data as applicable to ...
# 2207  Ability to interpret CT data as applicable to ...
# 2210  Ability to interpret CT data as applicable to ...
# 2211  Ability to interpret CT data as applicable to ...
# 2608  Ability to interpret CT data as applicable to ...
# 2223  Ability to interpret CT data as applicable to ...
# 2226  Ability to interpret CT data as applicable to ...
# 3543  Perform a variety of related duties such as wa...
# 3549  Perform a variety of related duties such as wa...
# 3567  Knowledge of UB, HCFA, ADA and other utilized ...
# 3552  Knowledge of UB, HCFA, ADA and other utilized ...
# 3544  Accuracy of data; The Research Study Assistant...
# 3548  Accuracy of data; The Research Study Assistant...
# 3541  Demonstrate the ability to input accurate data...
# 3566  Demonstrate the ability to input accurate data...
# 3540  Forensic Scientists who process evidence that ...
# 3539  Forensic Scientists who process evidence that ...
# 46    As part of the Residency program, you will rec...
# 867   Analyze mass spectrometry data analysis. One o...
# 873   Analyze mass spectrometry data analysis. One o...
#
#                                                   title  parsed_salary  \
# 5                                   VP of Data Services       300000.0
# 13                                  VP of Data Services       300000.0
# 427   Quantitative Analyst (Big Data Focus) at $10+ ...       250000.0
# 25    Vice President Engineering (Big Data/ Machine ...       227500.0
# 42    Vice President Engineering (Big Data/ Machine ...       227500.0
# 442   Quantitative Data Scientist - Large Asset Manager       225000.0
# 432                    VP - Predictive Modeling Actuary       215000.0
# 425                    VP - Predictive Modeling Actuary       215000.0
# 447     Machine Learning Research Scientist - Hedgefund       200000.0
# 414   Quantitative Analyst (Fundamental Quant Equiti...       200000.0
# 413                                      Data Scientist       200000.0
# 496                            JR. Full Stack Developer       200000.0
# 45                                       Java Developer       200000.0
# 506                            JR. Full Stack Developer       200000.0
# 436   Junior Quantitative Analyst / Developer for $5...       200000.0
# 3635  Quantitative Researcher, Machine Learning & Ba...       200000.0
# 3550             Senior Business Intelligence Scientist       190000.0
# 3542        Senior Business Intelligence Data Scientist       190000.0
# 3528                             Digital Data Scientist       190000.0
# 3537        Senior Business Intelligence Data Scientist       190000.0
# 3632                Manager of Data Science (Python, R)       185000.0
# 3641                   Assistant Director Biostatistics       185000.0
# 3643                   Assistant Director Biostatistics       185000.0
# 3646              Associate Director Statistics Phase I       185000.0
# 501               Executive Director of Data Governance       185000.0
# 3640                           Director of Data Science       180000.0
# 35             Staff Engineer, Machine Learning (Scala)       180000.0
# 47                                      Erlang Engineer       180000.0
# 0                                        Data Scientist       180000.0
# 440                                   VP Data Scientist       175000.0
# ...                                                 ...            ...
# 2240  Research Engineering/ Scientist Associate II -...         3210.0
# 2237  Research Engineering/ Scientist Associate II -...         3210.0
# 2233  Research Engineering/ Scientist Associate II -...         3210.0
# 2188  Research Engineering/ Scientist Associate II -...         3210.0
# 2232  Research Engineering/ Scientist Associate II -...         3210.0
# 2218  Research Engineering/ Scientist Associate II -...         3210.0
# 2214  Research Engineering/ Scientist Associate II -...         3210.0
# 2193  Research Engineering/ Scientist Associate II -...         3210.0
# 2195  Research Engineering/ Scientist Associate II -...         3210.0
# 2200  Research Engineering/ Scientist Associate II -...         3210.0
# 2202  Research Engineering/ Scientist Associate II -...         3210.0
# 2207  Research Engineering/ Scientist Associate II -...         3210.0
# 2210  Research Engineering/ Scientist Associate II -...         3210.0
# 2211  Research Engineering/ Scientist Associate II -...         3210.0
# 2608  Research Engineering/ Scientist Associate II -...         3210.0
# 2223  Research Engineering/ Scientist Associate II -...         3210.0
# 2226  Research Engineering/ Scientist Associate II -...         3210.0
# 3543                            DRIVER-WAREHOUSE WORKER         3139.5
# 3549                            DRIVER-WAREHOUSE WORKER         3139.5
# 3567            PATIENT FINANCIAL SERVICES SPECIALIST 2         3072.5
# 3552            PATIENT FINANCIAL SERVICES SPECIALIST 2         3072.5
# 3544                           RESEARCH STUDY ASSISTANT         2846.0
# 3548                           RESEARCH STUDY ASSISTANT         2846.0
# 3541                              STOCKROOM ATTENDANT 2         2749.5
# 3566                              STOCKROOM ATTENDANT 2         2749.5
# 3540                    PROPERTY AND EVIDENCE CUSTODIAN         2549.5
# 3539                    PROPERTY AND EVIDENCE CUSTODIAN         2549.5
# 46    Data Science Resident (DSR), Data Engineering ...         2500.0
# 867   Research Engineering/ Scientist Assistant - La...         2333.0
# 873   Research Engineering/ Scientist Assistant - La...         2333.0
#
#       binary_variable
# 5                   1
# 13                  1
# 427                 1
# 25                  1
# 42                  1
# 442                 1
# 432                 1
# 425                 1
# 447                 1
# 414                 1
# 413                 1
# 496                 1
# 45                  1
# 506                 1
# 436                 1
# 3635                1
# 3550                1
# 3542                1
# 3528                1
# 3537                1
# 3632                1
# 3641                1
# 3643                1
# 3646                1
# 501                 1
# 3640                1
# 35                  1
# 47                  1
# 0                   1
# 440                 1
# ...               ...
# 2240                0
# 2237                0
# 2233                0
# 2188                0
# 2232                0
# 2218                0
# 2214                0
# 2193                0
# 2195                0
# 2200                0
# 2202                0
# 2207                0
# 2210                0
# 2211                0
# 2608                0
# 2223                0
# 2226                0
# 3543                0
# 3549                0
# 3567                0
# 3552                0
# 3544                0
# 3548                0
# 3541                0
# 3566                0
# 3540                0
# 3539                0
# 46                  0
# 867                 0
# 873                 0
#
# [4789 rows x 7 columns]

# %% [markdown]
# #### Thought experiment: What is the baseline accuracy for this model?

# %%
# # YOUR CODE HERE
# #Calculate the accuracy with the accuracy_score() function from sklearn

# from sklearn.metrics import accuracy_score

# acc = accuracy_score(Y_test, Y_pred)
# print(acc)

# %% [markdown]
# #### Create a Logistic Regression model to predict High/Low salary using statsmodel. Start by ONLY using the location as a feature. Display the coefficients and write a short summary of what they mean.

# %%
## YOUR CODE HERE
dummy_ranks = pd.get_dummies(Top_Salary["city"], prefix="city")
cols_to_keep = ["city", "parsed_salary", "binary_variable"]
data = Top_Salary[cols_to_keep].join(dummy_ranks.ix[:, "city_2":])
#data["intercept"] = 1.0
cleaned_data = data.ix[:, 0:] #df.ix[rows, columns]

# %%
cleaned_data.columns
# Out:
# Index([u'city', u'parsed_salary', u'binary_variable', u'city_Austin',
#        u'city_Chicago', u'city_New+York', u'city_San+Francisco',
#        u'city_Seattle'],
#       dtype='object')

# %%
# data["binary_variable"] = Y
# cleaned_data = X # Should not contain target (["binary_variable"]) or ["city"] = column that
# you created dummy variables for

Y= data["binary_variable"]
X = cleaned_data.drop(['binary_variable', 'city', 'parsed_salary'], axis=1, inplace=False)

# %%
print X.shape
print Y.shape
print X.head()
# Out:
# (4789, 5)
# (4789,)
#      city_Austin  city_Chicago  city_New+York  city_San+Francisco  \
# 5            0.0           0.0            0.0                 1.0
# 13           0.0           0.0            0.0                 1.0
# 427          0.0           0.0            1.0                 0.0
# 25           0.0           0.0            0.0                 1.0
# 42           0.0           0.0            0.0                 1.0
#
#      city_Seattle
# 5             0.0
# 13            0.0
# 427           0.0
# 25            0.0
# 42            0.0

# %%
X.dtypes
# Out:
# city_Austin           float64
# city_Chicago          float64
# city_New+York         float64
# city_San+Francisco    float64
# city_Seattle          float64
# dtype: object

# %%
Y.head()
# Out:
# 5      1
# 13     1
# 427    1
# 25     1
# 42     1
# Name: binary_variable, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=77)

# %%
logreg = LogisticRegression(random_state=77)
logreg.fit(X_train, Y_train)
Y_pred = logreg.predict(X_test)

# %%
# Look at week4-4.2-demo2.ipynb for reference
print logreg.coef_
print logreg.intercept_
print logreg.n_iter_
# Out:
# [[-3.19617408  3.54527441  1.47156034  2.1529933  -2.57672089]]
# [ 1.39693308]
# [6]

# %%
#interpret coeffieints as odds 
print np.exp(logreg.coef_)
print np.exp(logreg.intercept_)
# Out:
# [[  0.04091846  34.64919207   4.35602673   8.61059396   0.07602288]]
# [ 4.04278205]

# %%
from sklearn.metrics import confusion_matrix
# the input format is almost always (test, predict), but always check with documentation!
conmat = np.array(confusion_matrix(Y_test, Y_pred))

confusion = pd.DataFrame(conmat, index=['Over Median (>74550.0)', 'Under Median(<74550.0)'],
                          columns=['Over Median (>74550.0)', 'Under Median(<74550.0)'])

print(confusion)
# Out:
#                         Over Median (>74550.0)  Under Median(<74550.0)
# Over Median (>74550.0)                     742                      18
# Under Median(<74550.0)                     147                     674

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
# %matplotlib inline


Y_score = logreg.decision_function(X_test)
print Y_score

FPR = dict()
TPR = dict()
ROC_AUC = dict()

# For class 1, find the area under the curve
FPR[1], TPR[1], _ = roc_curve(Y_test, Y_score)
ROC_AUC[1] = auc(FPR[1], TPR[1])

# Plot of a ROC curve for class 1 (has_cancer)
plt.figure(figsize=[11,9])
plt.plot(FPR[1], TPR[1], label='ROC curve (area = %0.2f)' % ROC_AUC[1], linewidth=4)
plt.plot([0, 1], [0, 1], 'k--', linewidth=4)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('Salary Detection', fontsize=18)
plt.legend(loc="lower right")
plt.show()
# Out:
# [ 3.54992638  3.54992638 -1.799241   ..., -1.799241   -1.799241    3.54992638]

# %% [markdown]
# #### Create a few new variables in your dataframe to represent interesting features of a job title.
# - For example, create a feature that represents whether 'Senior' is in the title
# - or whether 'Manager' is in the title.
# - Then build a new Logistic Regression model with these features. Do they add any value?

# %%
Status = df

# %%
Status['Status'] = Status['title'].map(lambda x: 1 if 'Senior' in x or 'Manager' in x or 'VP' in x or 'Vice President' in x or 'Director' in x or 'Sr.' in x else 0)

# %%
Status
# Out:
#                city                                company  \
# 0     San+Francisco                            MarkMonitor
# 1     San+Francisco                  Workbridge Associates
# 2     San+Francisco                               Mines.io
# 3     San+Francisco                  Workbridge Associates
# 4     San+Francisco                Smith Hanley Associates
# 5     San+Francisco                         HSF Consulting
# 6     San+Francisco                       All-In Analytics
# 7     San+Francisco                                Brilent
# 8     San+Francisco                         HSF Consulting
# 9     San+Francisco                       All-In Analytics
# 10    San+Francisco                     Jobspring Partners
# 11    San+Francisco      University of California Berkeley
# 12    San+Francisco                  Workbridge Associates
# 13    San+Francisco                         HSF Consulting
# 14    San+Francisco      University of California Berkeley
# 15    San+Francisco                  Workbridge Associates
# 16    San+Francisco                  Workbridge Associates
# 17    San+Francisco                  Workbridge Associates
# 18    San+Francisco                  Workbridge Associates
# 19    San+Francisco              Corporate Labs Technology
# 20    San+Francisco                                Brilent
# 21    San+Francisco                  Workbridge Associates
# 22    San+Francisco                                 3coast
# 23    San+Francisco      University of California Berkeley
# 24    San+Francisco                     NextGen Jane, Inc.
# 25    San+Francisco                     Jobspring Partners
# 26    San+Francisco                  Workbridge Associates
# 27    San+Francisco                  Workbridge Associates
# 28    San+Francisco                  Workbridge Associates
# 29    San+Francisco  Talent Compliance Consulting Services
# ...             ...                                    ...
# 4761        Chicago                  Workbridge Associates
# 4762        Chicago        Clinical Management Consultants
# 4763        Chicago                  Workbridge Associates
# 4764        Chicago        Clinical Management Consultants
# 4765        Chicago                  Workbridge Associates
# 4766        Chicago                  Workbridge Associates
# 4767        Chicago        Clinical Management Consultants
# 4768        Chicago                  Workbridge Associates
# 4769        Chicago                  Workbridge Associates
# 4770        Chicago        Clinical Management Consultants
# 4771        Chicago                  Workbridge Associates
# 4772        Chicago                  Workbridge Associates
# 4773        Chicago                  Workbridge Associates
# 4774        Chicago        Clinical Management Consultants
# 4775        Chicago                  Workbridge Associates
# 4776        Chicago                  Workbridge Associates
# 4777        Chicago        Clinical Management Consultants
# 4778        Chicago                  Workbridge Associates
# 4779        Chicago        Clinical Management Consultants
# 4780        Chicago                  Workbridge Associates
# 4781        Chicago        Clinical Management Consultants
# 4782        Chicago                  Workbridge Associates
# 4783        Chicago                  Workbridge Associates
# 4784        Chicago        Clinical Management Consultants
# 4785        Chicago                  Workbridge Associates
# 4786        Chicago                  Workbridge Associates
# 4787        Chicago        Clinical Management Consultants
# 4788        Chicago                  Workbridge Associates
# 4789        Chicago        Clinical Management Consultants
# 4790        Chicago                  Workbridge Associates
#
#                           salary  \
# 0                $180,000 a year
# 1     $130,000 - $180,000 a year
# 2      $80,000 - $120,000 a year
# 3     $150,000 - $180,000 a year
# 4                $140,000 a year
# 5                $300,000 a year
# 6     $100,000 - $150,000 a year
# 7                $130,000 a year
# 8                $160,000 a year
# 9     $100,000 - $150,000 a year
# 10    $150,000 - $175,000 a year
# 11       $3,811 - $3,889 a month
# 12    $100,000 - $200,000 a year
# 13               $300,000 a year
# 14      $43,692 - $51,120 a year
# 15    $130,000 - $180,000 a year
# 16    $100,000 - $200,000 a year
# 17    $130,000 - $150,000 a year
# 18    $100,000 - $140,000 a year
# 19    $110,000 - $180,000 a year
# 20               $150,000 a year
# 21    $140,000 - $200,000 a year
# 22     $80,000 - $200,000 a year
# 23      $67,500 - $81,600 a year
# 24                $65,000 a year
# 25    $180,000 - $275,000 a year
# 26    $130,000 - $150,000 a year
# 27    $100,000 - $140,000 a year
# 28    $140,000 - $200,000 a year
# 29               $100,000 a year
# ...                          ...
# 4761  $110,000 - $150,000 a year
# 4762    $71,384 - $93,274 a year
# 4763             $170,000 a year
# 4764    $71,384 - $93,274 a year
# 4765             $170,000 a year
# 4766  $110,000 - $150,000 a year
# 4767    $71,384 - $93,274 a year
# 4768             $170,000 a year
# 4769  $110,000 - $150,000 a year
# 4770    $71,384 - $93,274 a year
# 4771             $170,000 a year
# 4772  $110,000 - $150,000 a year
# 4773  $110,000 - $150,000 a year
# 4774    $71,384 - $93,274 a year
# 4775             $170,000 a year
# 4776  $110,000 - $150,000 a year
# 4777    $71,384 - $93,274 a year
# 4778             $170,000 a year
# 4779    $71,384 - $93,274 a year
# 4780             $170,000 a year
# 4781    $71,384 - $93,274 a year
# 4782             $170,000 a year
# 4783  $110,000 - $150,000 a year
# 4784    $71,384 - $93,274 a year
# 4785             $170,000 a year
# 4786  $110,000 - $150,000 a year
# 4787    $71,384 - $93,274 a year
# 4788             $170,000 a year
# 4789    $71,384 - $93,274 a year
# 4790             $170,000 a year
#
#                                                 summary  \
# 0     Data skills (SQL, Hive, Pig). Applying machine...
# 1     3+ years of industry experience in a data scie...
# 2     We are looking for a data scientist/developer ...
# 3     In this position you will share programming an...
# 4     This person will recruit, build and lead a tea...
# 5     Teams included Data Services(including data en...
# 6     Fraud Data Scientist. Seeking someone with ski...
# 7     Perform large-scale data analysis, find intere...
# 8     More data- they simply have more data than the...
# 9     Fraud Data Scientist. Seeking someone with ski...
# 10    Given the high volume of data collected by the...
# 11    Must be able to work in a greenhouse, manage d...
# 12    You will collaborate with Product, Data Engine...
# 13    Teams included Data Services(including data en...
# 14    Demonstrated experience with programming for b...
# 15    This leading company has a job opening for Pri...
# 16    You will collaborate with Product, Data Engine...
# 17    2+ years of experience in Data Scientist, Quan...
# 18    Solid experience in data science. Established ...
# 19    Machine Learning Developer Brisbane, CA Sign o...
# 20    The Brilent team brings together deep experien...
# 21    The Senior Data Scientist position requires a ...
# 22    VP - Predictive Modeling / Data Scientist. Han...
# 23    Ensures accuracy and completeness of data in m...
# 24    Scientific Researcher – Next Gen Sequencing Sc...
# 25    This is an opportunity to lead a team of talen...
# 26    2+ years of experience in Data Scientist, Quan...
# 27    Solid experience in data science. Established ...
# 28    The Senior Data Scientist position requires a ...
# 29    Strong data analysis skills including setting ...
# ...                                                 ...
# 4761  This agile team will create and develop new so...
# 4762  Manager Health Information Management Data Ana...
# 4763  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4764  Manager Health Information Management Data Ana...
# 4765  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4766  This agile team will create and develop new so...
# 4767  Manager Health Information Management Data Ana...
# 4768  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4769  This agile team will create and develop new so...
# 4770  Manager Health Information Management Data Ana...
# 4771  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4772  This agile team will create and develop new so...
# 4773  This agile team will create and develop new so...
# 4774  Manager Health Information Management Data Ana...
# 4775  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4776  This agile team will create and develop new so...
# 4777  Manager Health Information Management Data Ana...
# 4778  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4779  Manager Health Information Management Data Ana...
# 4780  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4781  Manager Health Information Management Data Ana...
# 4782  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4783  This agile team will create and develop new so...
# 4784  Manager Health Information Management Data Ana...
# 4785  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4786  This agile team will create and develop new so...
# 4787  Manager Health Information Management Data Ana...
# 4788  Big Data with Hadoop, Hive, Impala. Mid, Senio...
# 4789  Manager Health Information Management Data Ana...
# 4790  Big Data with Hadoop, Hive, Impala. Mid, Senio...
#
#                                                   title  parsed_salary  Status
# 0                                        Data Scientist       180000.0       0
# 1                                 Senior Data Scientist       155000.0       1
# 2                             Full-Stack Data Scientist       100000.0       0
# 3                                        Data Scientist       165000.0       0
# 4                                        Data Scientist       140000.0       0
# 5                                   VP of Data Services       300000.0       1
# 6                                  Fraud Data Scientist       125000.0       0
# 7                                 Senior Data Scientist       130000.0       1
# 8                                 Senior Data Scientist       160000.0       1
# 9                                  Fraud Data Scientist       125000.0       0
# 10                  Python Developer (Machine Learning)       162500.0       0
# 11                        Staff Research Associate, PMB         3850.0       0
# 12    Chief Algorithm Developer (Signal Processing) ...       150000.0       0
# 13                                  VP of Data Services       300000.0       1
# 14    Post-Doctoral Scholar-Employee: Analysis of om...        47406.0       0
# 15                             Principal Data Scientist       155000.0       0
# 16    Chief Algorithm Developer (Signal Processing) ...       150000.0       0
# 17                        Data Scientist (Econometrics)       140000.0       0
# 18                Data Scientist (Statistics/Economics)       120000.0       0
# 19                    Data Scientist (Machine Learning)       145000.0       0
# 20                        Senior NLP Scientist/Engineer       150000.0       1
# 21    Senior Data Scientist (Autonomous Vehicle Rese...       170000.0       1
# 22            VP - Predictive Modeling / Data Scientist       140000.0       1
# 23                          Database Administrator, GSE        74550.0       0
# 24                                Scientific Researcher        65000.0       0
# 25    Vice President Engineering (Big Data/ Machine ...       227500.0       1
# 26                        Data Scientist (Econometrics)       140000.0       0
# 27                Data Scientist (Statistics/Economics)       120000.0       0
# 28    Senior Data Scientist (Autonomous Vehicle Rese...       170000.0       1
# 29                            Quality Control Scientist       100000.0       0
# ...                                                 ...            ...     ...
# 4761                     Senior Java Computer Scientist       130000.0       1
# 4762  Manager Health Information Management Data Ana...        82329.0       1
# 4763                         Director of Data Analytics       170000.0       1
# 4764  Manager Health Information Management Data Ana...        82329.0       1
# 4765                         Director of Data Analytics       170000.0       1
# 4766                     Senior Java Computer Scientist       130000.0       1
# 4767  Manager Health Information Management Data Ana...        82329.0       1
# 4768                         Director of Data Analytics       170000.0       1
# 4769                     Senior Java Computer Scientist       130000.0       1
# 4770  Manager Health Information Management Data Ana...        82329.0       1
# 4771                         Director of Data Analytics       170000.0       1
# 4772                     Senior Java Computer Scientist       130000.0       1
# 4773                     Senior Java Computer Scientist       130000.0       1
# 4774  Manager Health Information Management Data Ana...        82329.0       1
# 4775                         Director of Data Analytics       170000.0       1
# 4776                     Senior Java Computer Scientist       130000.0       1
# 4777  Manager Health Information Management Data Ana...        82329.0       1
# 4778                         Director of Data Analytics       170000.0       1
# 4779  Manager Health Information Management Data Ana...        82329.0       1
# 4780                         Director of Data Analytics       170000.0       1
# 4781  Manager Health Information Management Data Ana...        82329.0       1
# 4782                         Director of Data Analytics       170000.0       1
# 4783                     Senior Java Computer Scientist       130000.0       1
# 4784  Manager Health Information Management Data Ana...        82329.0       1
# 4785                         Director of Data Analytics       170000.0       1
# 4786                     Senior Java Computer Scientist       130000.0       1
# 4787  Manager Health Information Management Data Ana...        82329.0       1
# 4788                         Director of Data Analytics       170000.0       1
# 4789  Manager Health Information Management Data Ana...        82329.0       1
# 4790                         Director of Data Analytics       170000.0       1
#
# [4791 rows x 7 columns]

# %% [markdown]
# #### Rebuild this model with scikit-learn.
# - You can either create the dummy features manually or use the `dmatrix` function from `patsy`
# - Remember to scale the feature variables as well!

# %%
## YOUR CODE HERE

import patsy
from patsy import dmatrices
from sklearn.cross_validation import train_test_split

# %%
formula = 'Status ~ C(title) + parsed_salary'
ymat, xmat = patsy.dmatrices(formula, data=Status)

# %%
Status.columns[4:6]
# Out:
# Index([u'title', u'parsed_salary'], dtype='object')

# %%
dfData = Status[list(Status.columns[4:6])]
dfTarget = Status['Status']

# %%
from sklearn.cross_validation import train_test_split

x_train, x_test, y_train, y_test = train_test_split(xmat, np.ravel(ymat), test_size=0.33, random_state = 77)
print x_train.shape
print x_test.shape
print y_train.shape
print y_test.shape
# Out:
# (3208, 185)
# (1581, 185)
# (3208,)
# (1581,)

# %%
logreg = LogisticRegression(random_state=77)
logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_test)

# %%
y_score = logreg.score(x_test, np.ravel(y_test))
y_score
# Out:
# 0.46932321315623021

# %%
from sklearn.metrics import confusion_matrix
# the input format is almost always (test, predict), but always check with documentation!
conmat = np.array(confusion_matrix(y_test, y_pred))

confusion = pd.DataFrame(conmat, index=['Contains Title', 'No Title'],
                          columns=['Contains Title', 'No Title'])

print(confusion)
# Out:
#                 Contains Title  No Title
# Contains Title               0       839
# No Title                     0       742

# %% [markdown]
# #### Use cross-validation in scikit-learn to evaluate the model above.
# - Evaluate the accuracy, AUC, precision and recall of the model.
# - Discuss the differences and explain when you want a high-recall or a high-precision model in this scenario.

# %%
# YOUR CODE HERE # Refer to Week04, lesson 2.3
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
# %matplotlib inline


y_score = logreg.decision_function(x_test)
print y_score

FPR = dict()
TPR = dict()
ROC_AUC = dict()

# For class 1, find the area under the curve
FPR[1], TPR[1], _ = roc_curve(y_test, y_score)
ROC_AUC[1] = auc(FPR[1], TPR[1])

# Plot of a ROC curve for class 1 (has_cancer)
plt.figure(figsize=[11,9])
plt.plot(FPR[1], TPR[1], label='ROC curve (area = %0.2f)' % ROC_AUC[1], linewidth=4)
plt.plot([0, 1], [0, 1], 'k--', linewidth=4)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('Salary by Status', fontsize=18)
plt.legend(loc="lower right")
plt.show()
#print "r^2:", model.score(x, y)
# Out:
# [ 0.10270306  0.07153638  0.99002699 ...,  0.03858527  0.07153649
#   1.80379761]

# %%
X_train2, X_test2, Y_train2, Y_test2 = train_test_split(X, Y, test_size=0.33)

logreg2 = LogisticRegression(penalty='l2')
logreg2.fit(X_train2, np.asarray(Y_train2, dtype=np.int64))
Y_pred2 = logreg2.predict(X_test2)

# %% [markdown]
# #### Compare L1 and L2 regularization for this logistic regression model. What effect does this have on the coefficients learned?

# %%
from sklearn.metrics import accuracy_score
print accuracy_score(Y_test.values.astype(int), Y_pred)
# Out:
# 0.895635673624

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test.values.astype(int), Y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.83      0.98      0.90       760
#           1       0.97      0.82      0.89       821
#
# avg / total       0.91      0.90      0.90      1581

# %% [markdown]
# #### Continue to incorporate other text features from the title or summary that you believe will predict the salary and examine their coefficients

# %% [markdown]
# #### Take ~100 scraped entries with salaries. Convert them to use with your model and predict the salary - which entries have the highest predicted salaries?

# %% [markdown]
# ### BONUS

# %% [markdown]
# #### Bonus: Use Count Vectorizer from scikit-learn to create features from the text summaries.
# - Examine using count or binary features in the model
# - Re-evaluate the logistic regression model using these. Does this improve the model performance?
# - What text features are the most valuable?

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Re-test L1 and L2 regularization. You can use LogisticRegressionCV to find the optimal reguarlization parameters.
# - Re-test what text features are most valuable.
# - How do L1 and L2 change the coefficients?

# %%
## YOUR CODE HERE
