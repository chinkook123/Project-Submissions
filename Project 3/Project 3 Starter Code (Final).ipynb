# %% [markdown]
# # Getting started
#
# Using a provided dataset, create a Linear Regression model and an executive summary write up based on your chosen scenario.
#
# # 1) Your work must: Identify the problem
#
# ### Write a high quality problem statement

# %% [markdown]
# Problem Statement: A liquor store owner in Iowa is looking to expand to new locations and has hired you to investigate the market data for potential new locations. The business owner is interested in the details of the best model you can fit to the data so that his team can evaluate potential locations for a new storefront.
#
# Describe the goals of your study and criteria for success
#
# Goal: Build models of total sales based on location, price per bottle, total bottles sold. You may find it useful to build models for each county, zip code, or city.
# Provide a table of the best performing stores by location type of your choice (city, county, or zip code) and the predictions of your model(s).
#
# Based on your models and the table of data, recommend some general locations to the business owner, taking into account model performance. Validate your model's performance and ability to predict future sales using cross-validation.
#
# Bonus: Recommend targets for volume sold and price per bottle!

# %% [markdown]
# # 2) Acquire the data
#
# Obtain the data here -- it's from Iowa.gov, filtered and reduced a bit
# There is a further reduced version that is 10% of the version above here

# %%
## Importing the packages that are needed for this project

import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import datetime as dt
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 3) Explore the data
#
# ### Import data using the Pandas Library

# %%
# Load the data into a DataFrame

file_name = ('/Users/ryangin/Desktop/General_Assembly/DSI_SM_01/projects/01-projects-weekly/project-03/Assets/Iowa_Liquor_sales_sample_10pct.csv')

# %%
df = pd.read_csv(file_name)
df.head()
# Out:
#          Date  Store Number         City Zip Code  County Number      County  \
# 0  11/04/2015          3717       SUMNER    50674            9.0      Bremer
# 1  03/02/2016          2614    DAVENPORT    52807           82.0       Scott
# 2  02/11/2016          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3  02/03/2016          2501         AMES    50010           85.0       Story
# 4  08/18/2015          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750             $4.50
# 1                    Tin Cup                 750            $13.75
# 2                   Jim Beam                1000            $12.59
# 3    1800 Ultimate Margarita                1750             $9.50
# 4         Five O'clock Vodka                1750             $7.20
#
#   State Bottle Retail  Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 0               $6.75            12         $81.00                   9.0
# 1              $20.63             2         $41.26                   1.5
# 2              $18.89            24        $453.36                  24.0
# 3              $14.25             6         $85.50                  10.5
# 4              $10.80            12        $129.60                  21.0
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40
# 2                   6.34
# 3                   2.77
# 4                   5.55

# %% [markdown]
# ### Perform exploratory analysis methods with visualization and statistical analysis
#
# References:
# week-03/1.4-lab/code/solution-code

# %%
df.dtypes
# Out:
# Date                      object
# Store Number               int64
# City                      object
# Zip Code                  object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number              int64
# Item Number                int64
# Item Description          object
# Bottle Volume (ml)         int64
# State Bottle Cost         object
# State Bottle Retail       object
# Bottles Sold               int64
# Sale (Dollars)            object
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtype: object

# %%
# Convert Date column to datetime type
#df['Date'] = pd.to_datetime(df['Date'], format ="%Y/%m/%d")
df['Date'] = pd.to_datetime(df['Date'], format ="%m/%d/%Y")

# %%
# Replaces all the $ in the dataset with a space
df_reg = df.replace({'\$': ''}, regex=True)

# %%
# Convert columns to float types
df_reg[['Bottle Volume (ml)', 'State Bottle Cost', 'State Bottle Retail', 'Sale (Dollars)']] = df_reg[['Bottle Volume (ml)', 'State Bottle Cost', 'State Bottle Retail', 'Sale (Dollars)']].astype(float)

# %%
df_reg.dtypes
# Out:
# Date                     datetime64[ns]
# Store Number                      int64
# City                             object
# Zip Code                         object
# County Number                   float64
# County                           object
# Category                        float64
# Category Name                    object
# Vendor Number                     int64
# Item Number                       int64
# Item Description                 object
# Bottle Volume (ml)              float64
# State Bottle Cost               float64
# State Bottle Retail             float64
# Bottles Sold                      int64
# Sale (Dollars)                  float64
# Volume Sold (Liters)            float64
# Volume Sold (Gallons)           float64
# dtype: object

# %%
df_reg.describe()
# Out:
#         Store Number  County Number      Category  Vendor Number  \
# count  270955.000000  269878.000000  2.708870e+05   270955.00000
# mean     3590.263701      57.231642  1.043888e+06      256.43443
# std       947.662050      27.341205  5.018211e+04      141.01489
# min      2106.000000       1.000000  1.011100e+06       10.00000
# 25%      2604.000000      31.000000  1.012200e+06      115.00000
# 50%      3722.000000      62.000000  1.031200e+06      260.00000
# 75%      4378.000000      77.000000  1.062310e+06      380.00000
# max      9023.000000      99.000000  1.701100e+06      978.00000
#
#          Item Number  Bottle Volume (ml)  State Bottle Cost  \
# count  270955.000000       270955.000000      270955.000000
# mean    45974.963300          924.830341           9.773281
# std     52757.043086          493.088489           7.047119
# min       168.000000           50.000000           0.890000
# 25%     26827.000000          750.000000           5.500000
# 50%     38176.000000          750.000000           8.000000
# 75%     64573.000000         1000.000000          11.920000
# max    995507.000000         6000.000000         425.000000
#
#        State Bottle Retail   Bottles Sold  Sale (Dollars)  \
# count        270955.000000  270955.000000   270955.000000
# mean             14.675760       9.871285      128.902375
# std              10.570145      24.040912      383.027369
# min               1.340000       1.000000        1.340000
# 25%               8.270000       2.000000       30.450000
# 50%              12.270000       6.000000       70.560000
# 75%              17.880000      12.000000      135.000000
# max             637.500000    2508.000000    36392.400000
#
#        Volume Sold (Liters)  Volume Sold (Gallons)
# count         270955.000000          270955.000000
# mean               8.981351               2.372830
# std               28.913690               7.638182
# min                0.100000               0.030000
# 25%                1.500000               0.400000
# 50%                5.250000               1.390000
# 75%               10.500000               2.770000
# max             2508.000000             662.540000

# %%
df_reg.shape
# Out:
# (270955, 18)

# %%
df_drop = df_reg.dropna()

# %%
df_drop.count()
# Out:
# Date                     269258
# Store Number             269258
# City                     269258
# Zip Code                 269258
# County Number            269258
# County                   269258
# Category                 269258
# Category Name            269258
# Vendor Number            269258
# Item Number              269258
# Item Description         269258
# Bottle Volume (ml)       269258
# State Bottle Cost        269258
# State Bottle Retail      269258
# Bottles Sold             269258
# Sale (Dollars)           269258
# Volume Sold (Liters)     269258
# Volume Sold (Gallons)    269258
# dtype: int64

# %%
iowa_sample = df_drop.sample(frac=0.1)

# %%
iowa_sample
# Out:
#              Date  Store Number             City Zip Code  County Number  \
# 238935 2015-07-27          4794       BURLINGTON    52601           29.0
# 236139 2015-01-27          4485          SANBORN    51248           71.0
# 120268 2016-01-25          5095      CARTER LAKE    51510           78.0
# 125042 2015-03-10          4167          DUBUQUE    52001           31.0
# 231563 2015-09-22          2619  WEST DES MOINES    50266           77.0
# 205035 2015-12-03          4686          CLINTON    52732           23.0
# 12561  2015-12-01          3443   COUNCIL BLUFFS    51503           78.0
# 15964  2015-11-30          2538         WATERLOO    50702            7.0
# 156648 2015-05-27          3825       DES MOINES    50316           77.0
# 56234  2016-03-08          5176     CEDAR RAPIDS    52405           57.0
# 93134  2016-01-05          4485          SANBORN    51248           71.0
# 265808 2015-01-12          2478          ALTOONA    50009           77.0
# 216532 2015-09-10          2663        URBANDALE    50322           77.0
# 199807 2015-11-09          2670       CORALVILLE    52241           52.0
# 222347 2015-11-17          4592       EMMETSBURG    50536           74.0
# 269957 2015-12-07          3525       WASHINGTON    52353           92.0
# 70916  2015-01-20          3704       EMMETSBURG    50536           74.0
# 61428  2015-11-03          4310         CHEROKEE    51012           18.0
# 91676  2015-12-30          2515       MASON CITY    50401           17.0
# 168715 2015-01-21          3584          OELWEIN    50662           33.0
# 192697 2015-09-08          3738          DUBUQUE    52001           31.0
# 99417  2015-06-01          3952       BETTENDORF    52722           82.0
# 55132  2015-01-22          4091       CLEAR LAKE    50428           17.0
# 269843 2015-10-13          4904        LARCHWOOD    51241           60.0
# 78690  2015-06-10          4437             AMES    50010           85.0
# 152969 2016-03-03          5196       CORALVILLE    52241           52.0
# 180793 2015-01-20          4291          CRESTON    50801           88.0
# 28743  2015-02-19          5069       LAKE MILLS    50450           95.0
# 137555 2015-08-19          3820       SIOUX CITY    51103           97.0
# 54572  2015-11-23          2585           ALGONA    50511           55.0
# ...           ...           ...              ...      ...            ...
# 23585  2015-06-24          3778       DES MOINES    50310           77.0
# 71588  2016-02-29          4604           NEWTON    50208           50.0
# 61921  2015-04-30          2806          CLINTON    52732           23.0
# 162868 2015-10-01          3858        DAVENPORT    52806           82.0
# 86917  2015-06-24          4568       SIOUX CITY    51108           97.0
# 193252 2015-08-05          2545        IOWA CITY    52245           52.0
# 106980 2016-03-01          4448        URBANDALE    50322           77.0
# 16212  2015-05-28          4345         GRINNELL    50112           79.0
# 176268 2015-11-20          3162        MUSCATINE    52761           70.0
# 21113  2015-11-24          5106           DEWITT    52742           23.0
# 177201 2016-03-22          2619  WEST DES MOINES    50266           77.0
# 177717 2016-02-01          3899  WEST DES MOINES    50266           77.0
# 252469 2015-05-22          3952       BETTENDORF    52722           82.0
# 194387 2015-01-26          4580       WASHINGTON    52353           92.0
# 202704 2015-06-17          3773     CEDAR RAPIDS    52401           57.0
# 48868  2015-05-27          5057       DES MOINES    50317           77.0
# 213759 2016-03-02          3762  WINDSOR HEIGHTS    50322           77.0
# 10387  2015-05-05          2665           WAUKEE    50263           25.0
# 144619 2015-08-12          2501             AMES    50010           85.0
# 228200 2016-01-05          3981     SIOUX CENTER    51250           84.0
# 31458  2015-07-27          5149       BURLINGTON    52601           29.0
# 153205 2015-04-29          3776        DAVENPORT    52806           82.0
# 139570 2016-03-21          2647     CEDAR RAPIDS    52411           57.0
# 143216 2015-08-03          4125          WAPELLO    52653           58.0
# 153660 2015-06-30          4116        LAKE VIEW    51450           81.0
# 207576 2015-05-06          2625        DAVENPORT    52804           82.0
# 148314 2016-03-14          2569     CEDAR RAPIDS    52402           57.0
# 9444   2015-04-16          4864          CLINTON    52733           23.0
# 80601  2015-04-15          3943           NEVADA    50201           85.0
# 40189  2015-04-30          4969       CLEAR LAKE    50428           17.0
#
#                County   Category                       Category Name  \
# 238935     Des Moines  1032080.0                      IMPORTED VODKA
# 236139        O'Brien  1081200.0                      CREAM LIQUEURS
# 120268  Pottawattamie  1081600.0                     WHISKEY LIQUEUR
# 125042        Dubuque  1012200.0                     SCOTCH WHISKIES
# 231563           Polk  1051010.0             AMERICAN GRAPE BRANDIES
# 205035        Clinton  1051010.0             AMERICAN GRAPE BRANDIES
# 12561   Pottawattamie  1062310.0                          SPICED RUM
# 15964      Black Hawk  1032080.0                      IMPORTED VODKA
# 156648           Polk  1031200.0                      VODKA FLAVORED
# 56234            Linn  1032200.0               IMPORTED VODKA - MISC
# 93134         O'Brien  1011500.0               STRAIGHT RYE WHISKIES
# 265808           Polk  1012200.0                     SCOTCH WHISKIES
# 216532           Polk  1041100.0                   AMERICAN DRY GINS
# 199807        Johnson  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 222347      Palo Alto  1012100.0                   CANADIAN WHISKIES
# 269957     Washington  1031080.0                      VODKA 80 PROOF
# 70916       Palo Alto  1031080.0                      VODKA 80 PROOF
# 61428        Cherokee  1012200.0                     SCOTCH WHISKIES
# 91676     Cerro Gordo  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM
# 168715        Fayette  1062310.0                          SPICED RUM
# 192697        Dubuque  1031080.0                      VODKA 80 PROOF
# 99417           Scott  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM
# 55132     Cerro Gordo  1041100.0                   AMERICAN DRY GINS
# 269843           Lyon  1031200.0                      VODKA FLAVORED
# 78690           Story  1012100.0                   CANADIAN WHISKIES
# 152969        Johnson  1031080.0                      VODKA 80 PROOF
# 180793          Union  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM
# 28743       Winnebago  1011200.0           STRAIGHT BOURBON WHISKIES
# 137555       Woodbury  1062300.0                        FLAVORED RUM
# 54572         Kossuth  1081600.0                     WHISKEY LIQUEUR
# ...               ...        ...                                 ...
# 23585            Polk  1031200.0                      VODKA FLAVORED
# 71588          Jasper  1051010.0             AMERICAN GRAPE BRANDIES
# 61921         Clinton  1071100.0                  AMERICAN COCKTAILS
# 162868          Scott  1012200.0                     SCOTCH WHISKIES
# 86917        Woodbury  1012100.0                   CANADIAN WHISKIES
# 193252        Johnson  1011100.0                    BLENDED WHISKIES
# 106980           Polk  1031080.0                      VODKA 80 PROOF
# 16212       Poweshiek  1081300.0                 PEPPERMINT SCHNAPPS
# 176268      Muscatine  1081300.0                 PEPPERMINT SCHNAPPS
# 21113         Clinton  1012210.0                  SINGLE MALT SCOTCH
# 177201           Polk  1042100.0                   IMPORTED DRY GINS
# 177717           Polk  1011100.0                    BLENDED WHISKIES
# 252469          Scott  1032200.0               IMPORTED VODKA - MISC
# 194387     Washington  1031080.0                      VODKA 80 PROOF
# 202704           Linn  1081700.0         DISTILLED SPIRITS SPECIALTY
# 48868            Polk  1081600.0                     WHISKEY LIQUEUR
# 213759           Polk  1011200.0           STRAIGHT BOURBON WHISKIES
# 10387          Dallas  1012200.0                     SCOTCH WHISKIES
# 144619          Story  1031080.0                      VODKA 80 PROOF
# 228200          Sioux  1012200.0                     SCOTCH WHISKIES
# 31458      Des Moines  1012100.0                   CANADIAN WHISKIES
# 153205          Scott  1031200.0                      VODKA FLAVORED
# 139570           Linn  1031080.0                      VODKA 80 PROOF
# 143216         Louisa  1031200.0                      VODKA FLAVORED
# 153660            Sac  1071100.0                  AMERICAN COCKTAILS
# 207576          Scott  1011200.0           STRAIGHT BOURBON WHISKIES
# 148314           Linn  1062310.0                          SPICED RUM
# 9444          Clinton  1012100.0                   CANADIAN WHISKIES
# 80601           Story  1032080.0                      IMPORTED VODKA
# 40189     Cerro Gordo  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
#
#         Vendor Number  Item Number  \
# 238935             35        34425
# 236139            330        80457
# 120268            421        64858
# 125042             55         8827
# 231563            115        53211
# 205035            205        52594
# 12561             259        43022
# 15964             962        36406
# 156648            205        40192
# 56234             260        64572
# 93134             255        27102
# 265808            260         5326
# 216532             65        30236
# 199807            389        65896
# 222347            115        11777
# 269957            297        35918
# 70916             297        35918
# 61428              55         8826
# 91676              35        43127
# 168715            260         1799
# 192697             55        37936
# 99417             297        44603
# 55132             370        32236
# 269843            260        41077
# 78690             115        10550
# 152969            205        36969
# 180793             35        43037
# 28743              65        27682
# 137555             65        44499
# 54572             421        64867
# ...               ...          ...
# 23585             205        40192
# 71588             205        52596
# 61921             395        58873
# 162868             55         8825
# 86917             260        10803
# 193252             65        22786
# 106980            434        36304
# 16212             434        81204
# 176268            434        80578
# 21113              65         5446
# 177201            260        28868
# 177717            260        25606
# 252469            277        34881
# 194387            297        35914
# 202704            434        75087
# 48868             421        64858
# 213759             85        22216
# 10387              55         8828
# 144619            380        37346
# 228200            260         4626
# 31458             115        11774
# 153205            260        77842
# 139570            260        37993
# 143216            255        40092
# 153660             55        57157
# 207576            259        17956
# 148314            395        46504
# 9444              260        11290
# 80601             370        34007
# 40189              55        64601
#
#                                   Item Description  Bottle Volume (ml)  \
# 238935                            Grey Goose Vodka              1750.0
# 236139                        Ryan's Cream Liqueur              1000.0
# 120268    Fireball Cinnamon Whiskey Mini Dispenser              3000.0
# 125042                                    Lauder's              1000.0
# 231563                  Paul Masson Vs Brandy Mini               600.0
# 205035                             E & J Vs Brandy               375.0
# 12561               Admiral Nelson Spiced Rum Mini               500.0
# 15964                                  Medea Vodka               750.0
# 156648                     New Amsterdam Pineapple               375.0
# 56234                              Ciroc Pineapple               375.0
# 93134                                Templeton Rye               750.0
# 265808                        Johnnie Walker Black               750.0
# 216532                     Gilbey's Gin London Dry               750.0
# 199807                                 Metaxa Ouzo               750.0
# 222347                                Black Velvet              1000.0
# 269957                          Five O'clock Vodka              1750.0
# 70916                           Five O'clock Vodka              1750.0
# 61428                              Lauder's Scotch               750.0
# 91676                         Bacardi Superior Rum              1000.0
# 168715                Captain Morgan Spiced Barrel              1750.0
# 192697                                  Skol Vodka               750.0
# 99417                                 Five O'clock              1000.0
# 55132                       Seagrams Extra Dry Gin               750.0
# 269843                     Jeremiah Weed Sweet Tea              1000.0
# 78690                 Black Velvet Toasted Caramel               750.0
# 152969                         New Amsterdam Vodka               750.0
# 180793                            Bacardi Gold Rum              1000.0
# 28743                       Jim Beam Kentucky Fire               750.0
# 137555                            Cruzan Mango Rum               750.0
# 54572                    Fireball Cinnamon Whiskey              1000.0
# ...                                            ...                 ...
# 23585                      New Amsterdam Pineapple               375.0
# 71588                                     E & J Vs               750.0
# 61921   Jose Cuervo Authentic Watermelon Margarita              1750.0
# 162868                    Lauder's Scotch Traveler               750.0
# 86917                 Crown Royal Regal Apple Mini               300.0
# 193252                    Beam's 8 Star Bl Whiskey               750.0
# 106980                               Hawkeye Vodka               375.0
# 16212                Paramount Peppermint Schnapps               375.0
# 176268                   Arrow Peppermint Schnapps              1750.0
# 21113           Laphroaig 10 Yr Single Malt Scotch               750.0
# 177201                               Tanqueray Gin              1750.0
# 177717                 Seagrams 7 Crown Bl Whiskey               750.0
# 252469            Stolichnaya Vanil Vodka 75 Proof              1000.0
# 194387                          Five O'clock Vodka               375.0
# 202704                             Juarez Gold Dss              1000.0
# 48868     Fireball Cinnamon Whiskey Mini Dispenser              3000.0
# 213759                    Woodford Reserve Bourbon               750.0
# 10387                                     Lauder's              1750.0
# 144619                              Phillips Vodka               750.0
# 228200              Buchanan's 12 Yr Deluxe Scotch               750.0
# 31458                                 Black Velvet               375.0
# 153205                         Smirnoff Strawberry               750.0
# 139570                       Smirnoff Vodka 80 Prf               200.0
# 143216          Seagram's Red Berry Flavored Vodka               750.0
# 153660                 Chi-Chi's Pina Colada W/rum              1750.0
# 207576                   Evan Williams Str Bourbon               750.0
# 148314                     Kraken Black Spiced Rum               750.0
# 9444              Crown Royal Canadian Whisky Mini               300.0
# 80601                 Absolut Swedish Vodka 80 Prf              1000.0
# 40189                         Caravella Limoncello               750.0
#
#         State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 238935              35.42                53.13             2          106.26
# 236139               7.23                10.85             3           32.55
# 120268              29.72                44.58             8          356.64
# 125042               6.14                 9.21            12          110.52
# 231563               7.12                10.68             1           10.68
# 205035               3.22                 4.83             2            9.66
# 12561                3.78                 5.67             1            5.67
# 15964               18.84                28.26             2           56.52
# 156648               3.50                 5.25            24          126.00
# 56234                9.25                13.88             1           13.88
# 93134               18.09                27.14             2           54.28
# 265808              20.75                31.13             1           31.13
# 216532               4.72                 7.08            12           84.96
# 199807              10.50                15.75             2           31.50
# 222347               6.63                 9.95            12          119.40
# 269957               7.20                10.80             6           64.80
# 70916                7.20                10.80             6           64.80
# 61428                5.13                 7.70             2           15.40
# 91676                9.50                14.25            12          171.00
# 168715              18.00                27.00             6          162.00
# 192697               3.64                 5.46            12           65.52
# 99417                4.37                 6.56            24          157.44
# 55132                6.49                 9.74             4           38.96
# 269843              10.50                15.75             3           47.25
# 78690                6.75                10.13             6           60.78
# 152969               6.90                10.35             2           20.70
# 180793               9.50                14.25             1           14.25
# 28743               11.03                16.55             6           99.30
# 137555               6.83                10.25            12          123.00
# 54572               11.34                17.01            12          204.12
# ...                   ...                  ...           ...             ...
# 23585                3.50                 5.25             6           31.50
# 71588                6.00                 9.00             2           18.00
# 61921                8.20                12.30             6           73.80
# 162868               4.63                 7.20             3           21.60
# 86917                7.35                11.03             4           44.12
# 193252               3.67                 5.51             4           22.04
# 106980               1.86                 2.79            10           27.90
# 16212                2.28                 3.42             3           10.26
# 176268               7.05                10.58             6           63.48
# 21113               26.24                39.36             1           39.36
# 177201              24.99                37.49             6          224.94
# 177717               7.00                10.50            12          126.00
# 252469              15.97                23.96            12          287.52
# 194387               1.93                 2.90            24           69.60
# 202704               4.92                 7.38            12           88.56
# 48868               29.72                44.58             1           44.58
# 213759              21.02                31.53             1           31.53
# 10387               10.68                16.27             6           97.62
# 144619               3.57                 5.36            12           64.32
# 228200              21.99                32.99            12          395.88
# 31458                3.07                 4.61             5           23.05
# 153205               8.25                12.38            12          148.56
# 139570               2.54                 3.81             2            7.62
# 143216               5.38                 8.07             3           24.21
# 153660               6.00                 9.25             6           55.50
# 207576               6.81                10.55             4           42.20
# 148314              10.00                15.00             3           45.00
# 9444                 7.35                11.03            10          110.30
# 80601               14.99                22.49             1           22.49
# 40189               11.25                16.88             2           33.76
#
#         Volume Sold (Liters)  Volume Sold (Gallons)
# 238935                  3.50                   0.92
# 236139                  3.00                   0.79
# 120268                 24.00                   6.34
# 125042                 12.00                   3.17
# 231563                  0.60                   0.16
# 205035                  0.75                   0.20
# 12561                   0.50                   0.13
# 15964                   1.50                   0.40
# 156648                  9.00                   2.38
# 56234                   0.38                   0.10
# 93134                   1.50                   0.40
# 265808                  0.75                   0.20
# 216532                  9.00                   2.38
# 199807                  1.50                   0.40
# 222347                 12.00                   3.17
# 269957                 10.50                   2.77
# 70916                  10.50                   2.77
# 61428                   1.50                   0.40
# 91676                  12.00                   3.17
# 168715                 10.50                   2.77
# 192697                  9.00                   2.38
# 99417                  24.00                   6.34
# 55132                   3.00                   0.79
# 269843                  3.00                   0.79
# 78690                   4.50                   1.19
# 152969                  1.50                   0.40
# 180793                  1.00                   0.26
# 28743                   4.50                   1.19
# 137555                  9.00                   2.38
# 54572                  12.00                   3.17
# ...                      ...                    ...
# 23585                   2.25                   0.59
# 71588                   1.50                   0.40
# 61921                  10.50                   2.77
# 162868                  2.25                   0.59
# 86917                   1.20                   0.32
# 193252                  3.00                   0.79
# 106980                  3.75                   0.99
# 16212                   1.12                   0.30
# 176268                 10.50                   2.77
# 21113                   0.75                   0.20
# 177201                 10.50                   2.77
# 177717                  9.00                   2.38
# 252469                 12.00                   3.17
# 194387                  9.00                   2.38
# 202704                 12.00                   3.17
# 48868                   3.00                   0.79
# 213759                  0.75                   0.20
# 10387                  10.50                   2.77
# 144619                  9.00                   2.38
# 228200                  9.00                   2.38
# 31458                   1.88                   0.50
# 153205                  9.00                   2.38
# 139570                  0.40                   0.11
# 143216                  2.25                   0.59
# 153660                 10.50                   2.77
# 207576                  3.00                   0.79
# 148314                  2.25                   0.59
# 9444                    3.00                   0.79
# 80601                   1.00                   0.26
# 40189                   1.50                   0.40
#
# [26926 rows x 18 columns]

# %%
iowa_sample.shape
# Out:
# (26926, 18)

# %%
iowa_sample.to_csv('Iowa_Liquor_sales_small.csv', index=False)

# %%
new_sample = pd.read_csv('Iowa_Liquor_sales_small.csv')

# %%
new_sample.shape
# Out:
# (26926, 18)

# %%
new_sample
# Out:
#              Date  Store Number             City Zip Code  County Number  \
# 0      2015-07-27          4794       BURLINGTON    52601           29.0
# 1      2015-01-27          4485          SANBORN    51248           71.0
# 2      2016-01-25          5095      CARTER LAKE    51510           78.0
# 3      2015-03-10          4167          DUBUQUE    52001           31.0
# 4      2015-09-22          2619  WEST DES MOINES    50266           77.0
# 5      2015-12-03          4686          CLINTON    52732           23.0
# 6      2015-12-01          3443   COUNCIL BLUFFS    51503           78.0
# 7      2015-11-30          2538         WATERLOO    50702            7.0
# 8      2015-05-27          3825       DES MOINES    50316           77.0
# 9      2016-03-08          5176     CEDAR RAPIDS    52405           57.0
# 10     2016-01-05          4485          SANBORN    51248           71.0
# 11     2015-01-12          2478          ALTOONA    50009           77.0
# 12     2015-09-10          2663        URBANDALE    50322           77.0
# 13     2015-11-09          2670       CORALVILLE    52241           52.0
# 14     2015-11-17          4592       EMMETSBURG    50536           74.0
# 15     2015-12-07          3525       WASHINGTON    52353           92.0
# 16     2015-01-20          3704       EMMETSBURG    50536           74.0
# 17     2015-11-03          4310         CHEROKEE    51012           18.0
# 18     2015-12-30          2515       MASON CITY    50401           17.0
# 19     2015-01-21          3584          OELWEIN    50662           33.0
# 20     2015-09-08          3738          DUBUQUE    52001           31.0
# 21     2015-06-01          3952       BETTENDORF    52722           82.0
# 22     2015-01-22          4091       CLEAR LAKE    50428           17.0
# 23     2015-10-13          4904        LARCHWOOD    51241           60.0
# 24     2015-06-10          4437             AMES    50010           85.0
# 25     2016-03-03          5196       CORALVILLE    52241           52.0
# 26     2015-01-20          4291          CRESTON    50801           88.0
# 27     2015-02-19          5069       LAKE MILLS    50450           95.0
# 28     2015-08-19          3820       SIOUX CITY    51103           97.0
# 29     2015-11-23          2585           ALGONA    50511           55.0
# ...           ...           ...              ...      ...            ...
# 26896  2015-06-24          3778       DES MOINES    50310           77.0
# 26897  2016-02-29          4604           NEWTON    50208           50.0
# 26898  2015-04-30          2806          CLINTON    52732           23.0
# 26899  2015-10-01          3858        DAVENPORT    52806           82.0
# 26900  2015-06-24          4568       SIOUX CITY    51108           97.0
# 26901  2015-08-05          2545        IOWA CITY    52245           52.0
# 26902  2016-03-01          4448        URBANDALE    50322           77.0
# 26903  2015-05-28          4345         GRINNELL    50112           79.0
# 26904  2015-11-20          3162        MUSCATINE    52761           70.0
# 26905  2015-11-24          5106           DEWITT    52742           23.0
# 26906  2016-03-22          2619  WEST DES MOINES    50266           77.0
# 26907  2016-02-01          3899  WEST DES MOINES    50266           77.0
# 26908  2015-05-22          3952       BETTENDORF    52722           82.0
# 26909  2015-01-26          4580       WASHINGTON    52353           92.0
# 26910  2015-06-17          3773     CEDAR RAPIDS    52401           57.0
# 26911  2015-05-27          5057       DES MOINES    50317           77.0
# 26912  2016-03-02          3762  WINDSOR HEIGHTS    50322           77.0
# 26913  2015-05-05          2665           WAUKEE    50263           25.0
# 26914  2015-08-12          2501             AMES    50010           85.0
# 26915  2016-01-05          3981     SIOUX CENTER    51250           84.0
# 26916  2015-07-27          5149       BURLINGTON    52601           29.0
# 26917  2015-04-29          3776        DAVENPORT    52806           82.0
# 26918  2016-03-21          2647     CEDAR RAPIDS    52411           57.0
# 26919  2015-08-03          4125          WAPELLO    52653           58.0
# 26920  2015-06-30          4116        LAKE VIEW    51450           81.0
# 26921  2015-05-06          2625        DAVENPORT    52804           82.0
# 26922  2016-03-14          2569     CEDAR RAPIDS    52402           57.0
# 26923  2015-04-16          4864          CLINTON    52733           23.0
# 26924  2015-04-15          3943           NEVADA    50201           85.0
# 26925  2015-04-30          4969       CLEAR LAKE    50428           17.0
#
#               County   Category                       Category Name  \
# 0         Des Moines  1032080.0                      IMPORTED VODKA
# 1            O'Brien  1081200.0                      CREAM LIQUEURS
# 2      Pottawattamie  1081600.0                     WHISKEY LIQUEUR
# 3            Dubuque  1012200.0                     SCOTCH WHISKIES
# 4               Polk  1051010.0             AMERICAN GRAPE BRANDIES
# 5            Clinton  1051010.0             AMERICAN GRAPE BRANDIES
# 6      Pottawattamie  1062310.0                          SPICED RUM
# 7         Black Hawk  1032080.0                      IMPORTED VODKA
# 8               Polk  1031200.0                      VODKA FLAVORED
# 9               Linn  1032200.0               IMPORTED VODKA - MISC
# 10           O'Brien  1011500.0               STRAIGHT RYE WHISKIES
# 11              Polk  1012200.0                     SCOTCH WHISKIES
# 12              Polk  1041100.0                   AMERICAN DRY GINS
# 13           Johnson  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 14         Palo Alto  1012100.0                   CANADIAN WHISKIES
# 15        Washington  1031080.0                      VODKA 80 PROOF
# 16         Palo Alto  1031080.0                      VODKA 80 PROOF
# 17          Cherokee  1012200.0                     SCOTCH WHISKIES
# 18       Cerro Gordo  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM
# 19           Fayette  1062310.0                          SPICED RUM
# 20           Dubuque  1031080.0                      VODKA 80 PROOF
# 21             Scott  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM
# 22       Cerro Gordo  1041100.0                   AMERICAN DRY GINS
# 23              Lyon  1031200.0                      VODKA FLAVORED
# 24             Story  1012100.0                   CANADIAN WHISKIES
# 25           Johnson  1031080.0                      VODKA 80 PROOF
# 26             Union  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM
# 27         Winnebago  1011200.0           STRAIGHT BOURBON WHISKIES
# 28          Woodbury  1062300.0                        FLAVORED RUM
# 29           Kossuth  1081600.0                     WHISKEY LIQUEUR
# ...              ...        ...                                 ...
# 26896           Polk  1031200.0                      VODKA FLAVORED
# 26897         Jasper  1051010.0             AMERICAN GRAPE BRANDIES
# 26898        Clinton  1071100.0                  AMERICAN COCKTAILS
# 26899          Scott  1012200.0                     SCOTCH WHISKIES
# 26900       Woodbury  1012100.0                   CANADIAN WHISKIES
# 26901        Johnson  1011100.0                    BLENDED WHISKIES
# 26902           Polk  1031080.0                      VODKA 80 PROOF
# 26903      Poweshiek  1081300.0                 PEPPERMINT SCHNAPPS
# 26904      Muscatine  1081300.0                 PEPPERMINT SCHNAPPS
# 26905        Clinton  1012210.0                  SINGLE MALT SCOTCH
# 26906           Polk  1042100.0                   IMPORTED DRY GINS
# 26907           Polk  1011100.0                    BLENDED WHISKIES
# 26908          Scott  1032200.0               IMPORTED VODKA - MISC
# 26909     Washington  1031080.0                      VODKA 80 PROOF
# 26910           Linn  1081700.0         DISTILLED SPIRITS SPECIALTY
# 26911           Polk  1081600.0                     WHISKEY LIQUEUR
# 26912           Polk  1011200.0           STRAIGHT BOURBON WHISKIES
# 26913         Dallas  1012200.0                     SCOTCH WHISKIES
# 26914          Story  1031080.0                      VODKA 80 PROOF
# 26915          Sioux  1012200.0                     SCOTCH WHISKIES
# 26916     Des Moines  1012100.0                   CANADIAN WHISKIES
# 26917          Scott  1031200.0                      VODKA FLAVORED
# 26918           Linn  1031080.0                      VODKA 80 PROOF
# 26919         Louisa  1031200.0                      VODKA FLAVORED
# 26920            Sac  1071100.0                  AMERICAN COCKTAILS
# 26921          Scott  1011200.0           STRAIGHT BOURBON WHISKIES
# 26922           Linn  1062310.0                          SPICED RUM
# 26923        Clinton  1012100.0                   CANADIAN WHISKIES
# 26924          Story  1032080.0                      IMPORTED VODKA
# 26925    Cerro Gordo  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
#
#        Vendor Number  Item Number                            Item Description  \
# 0                 35        34425                            Grey Goose Vodka
# 1                330        80457                        Ryan's Cream Liqueur
# 2                421        64858    Fireball Cinnamon Whiskey Mini Dispenser
# 3                 55         8827                                    Lauder's
# 4                115        53211                  Paul Masson Vs Brandy Mini
# 5                205        52594                             E & J Vs Brandy
# 6                259        43022              Admiral Nelson Spiced Rum Mini
# 7                962        36406                                 Medea Vodka
# 8                205        40192                     New Amsterdam Pineapple
# 9                260        64572                             Ciroc Pineapple
# 10               255        27102                               Templeton Rye
# 11               260         5326                        Johnnie Walker Black
# 12                65        30236                     Gilbey's Gin London Dry
# 13               389        65896                                 Metaxa Ouzo
# 14               115        11777                                Black Velvet
# 15               297        35918                          Five O'clock Vodka
# 16               297        35918                          Five O'clock Vodka
# 17                55         8826                             Lauder's Scotch
# 18                35        43127                        Bacardi Superior Rum
# 19               260         1799                Captain Morgan Spiced Barrel
# 20                55        37936                                  Skol Vodka
# 21               297        44603                                Five O'clock
# 22               370        32236                      Seagrams Extra Dry Gin
# 23               260        41077                     Jeremiah Weed Sweet Tea
# 24               115        10550                Black Velvet Toasted Caramel
# 25               205        36969                         New Amsterdam Vodka
# 26                35        43037                            Bacardi Gold Rum
# 27                65        27682                      Jim Beam Kentucky Fire
# 28                65        44499                            Cruzan Mango Rum
# 29               421        64867                   Fireball Cinnamon Whiskey
# ...              ...          ...                                         ...
# 26896            205        40192                     New Amsterdam Pineapple
# 26897            205        52596                                    E & J Vs
# 26898            395        58873  Jose Cuervo Authentic Watermelon Margarita
# 26899             55         8825                    Lauder's Scotch Traveler
# 26900            260        10803                Crown Royal Regal Apple Mini
# 26901             65        22786                    Beam's 8 Star Bl Whiskey
# 26902            434        36304                               Hawkeye Vodka
# 26903            434        81204               Paramount Peppermint Schnapps
# 26904            434        80578                   Arrow Peppermint Schnapps
# 26905             65         5446          Laphroaig 10 Yr Single Malt Scotch
# 26906            260        28868                               Tanqueray Gin
# 26907            260        25606                 Seagrams 7 Crown Bl Whiskey
# 26908            277        34881            Stolichnaya Vanil Vodka 75 Proof
# 26909            297        35914                          Five O'clock Vodka
# 26910            434        75087                             Juarez Gold Dss
# 26911            421        64858    Fireball Cinnamon Whiskey Mini Dispenser
# 26912             85        22216                    Woodford Reserve Bourbon
# 26913             55         8828                                    Lauder's
# 26914            380        37346                              Phillips Vodka
# 26915            260         4626              Buchanan's 12 Yr Deluxe Scotch
# 26916            115        11774                                Black Velvet
# 26917            260        77842                         Smirnoff Strawberry
# 26918            260        37993                       Smirnoff Vodka 80 Prf
# 26919            255        40092          Seagram's Red Berry Flavored Vodka
# 26920             55        57157                 Chi-Chi's Pina Colada W/rum
# 26921            259        17956                   Evan Williams Str Bourbon
# 26922            395        46504                     Kraken Black Spiced Rum
# 26923            260        11290            Crown Royal Canadian Whisky Mini
# 26924            370        34007                Absolut Swedish Vodka 80 Prf
# 26925             55        64601                        Caravella Limoncello
#
#        Bottle Volume (ml)  State Bottle Cost  State Bottle Retail  \
# 0                  1750.0              35.42                53.13
# 1                  1000.0               7.23                10.85
# 2                  3000.0              29.72                44.58
# 3                  1000.0               6.14                 9.21
# 4                   600.0               7.12                10.68
# 5                   375.0               3.22                 4.83
# 6                   500.0               3.78                 5.67
# 7                   750.0              18.84                28.26
# 8                   375.0               3.50                 5.25
# 9                   375.0               9.25                13.88
# 10                  750.0              18.09                27.14
# 11                  750.0              20.75                31.13
# 12                  750.0               4.72                 7.08
# 13                  750.0              10.50                15.75
# 14                 1000.0               6.63                 9.95
# 15                 1750.0               7.20                10.80
# 16                 1750.0               7.20                10.80
# 17                  750.0               5.13                 7.70
# 18                 1000.0               9.50                14.25
# 19                 1750.0              18.00                27.00
# 20                  750.0               3.64                 5.46
# 21                 1000.0               4.37                 6.56
# 22                  750.0               6.49                 9.74
# 23                 1000.0              10.50                15.75
# 24                  750.0               6.75                10.13
# 25                  750.0               6.90                10.35
# 26                 1000.0               9.50                14.25
# 27                  750.0              11.03                16.55
# 28                  750.0               6.83                10.25
# 29                 1000.0              11.34                17.01
# ...                   ...                ...                  ...
# 26896               375.0               3.50                 5.25
# 26897               750.0               6.00                 9.00
# 26898              1750.0               8.20                12.30
# 26899               750.0               4.63                 7.20
# 26900               300.0               7.35                11.03
# 26901               750.0               3.67                 5.51
# 26902               375.0               1.86                 2.79
# 26903               375.0               2.28                 3.42
# 26904              1750.0               7.05                10.58
# 26905               750.0              26.24                39.36
# 26906              1750.0              24.99                37.49
# 26907               750.0               7.00                10.50
# 26908              1000.0              15.97                23.96
# 26909               375.0               1.93                 2.90
# 26910              1000.0               4.92                 7.38
# 26911              3000.0              29.72                44.58
# 26912               750.0              21.02                31.53
# 26913              1750.0              10.68                16.27
# 26914               750.0               3.57                 5.36
# 26915               750.0              21.99                32.99
# 26916               375.0               3.07                 4.61
# 26917               750.0               8.25                12.38
# 26918               200.0               2.54                 3.81
# 26919               750.0               5.38                 8.07
# 26920              1750.0               6.00                 9.25
# 26921               750.0               6.81                10.55
# 26922               750.0              10.00                15.00
# 26923               300.0               7.35                11.03
# 26924              1000.0              14.99                22.49
# 26925               750.0              11.25                16.88
#
#        Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 0                 2          106.26                  3.50
# 1                 3           32.55                  3.00
# 2                 8          356.64                 24.00
# 3                12          110.52                 12.00
# 4                 1           10.68                  0.60
# 5                 2            9.66                  0.75
# 6                 1            5.67                  0.50
# 7                 2           56.52                  1.50
# 8                24          126.00                  9.00
# 9                 1           13.88                  0.38
# 10                2           54.28                  1.50
# 11                1           31.13                  0.75
# 12               12           84.96                  9.00
# 13                2           31.50                  1.50
# 14               12          119.40                 12.00
# 15                6           64.80                 10.50
# 16                6           64.80                 10.50
# 17                2           15.40                  1.50
# 18               12          171.00                 12.00
# 19                6          162.00                 10.50
# 20               12           65.52                  9.00
# 21               24          157.44                 24.00
# 22                4           38.96                  3.00
# 23                3           47.25                  3.00
# 24                6           60.78                  4.50
# 25                2           20.70                  1.50
# 26                1           14.25                  1.00
# 27                6           99.30                  4.50
# 28               12          123.00                  9.00
# 29               12          204.12                 12.00
# ...             ...             ...                   ...
# 26896             6           31.50                  2.25
# 26897             2           18.00                  1.50
# 26898             6           73.80                 10.50
# 26899             3           21.60                  2.25
# 26900             4           44.12                  1.20
# 26901             4           22.04                  3.00
# 26902            10           27.90                  3.75
# 26903             3           10.26                  1.12
# 26904             6           63.48                 10.50
# 26905             1           39.36                  0.75
# 26906             6          224.94                 10.50
# 26907            12          126.00                  9.00
# 26908            12          287.52                 12.00
# 26909            24           69.60                  9.00
# 26910            12           88.56                 12.00
# 26911             1           44.58                  3.00
# 26912             1           31.53                  0.75
# 26913             6           97.62                 10.50
# 26914            12           64.32                  9.00
# 26915            12          395.88                  9.00
# 26916             5           23.05                  1.88
# 26917            12          148.56                  9.00
# 26918             2            7.62                  0.40
# 26919             3           24.21                  2.25
# 26920             6           55.50                 10.50
# 26921             4           42.20                  3.00
# 26922             3           45.00                  2.25
# 26923            10          110.30                  3.00
# 26924             1           22.49                  1.00
# 26925             2           33.76                  1.50
#
#        Volume Sold (Gallons)
# 0                       0.92
# 1                       0.79
# 2                       6.34
# 3                       3.17
# 4                       0.16
# 5                       0.20
# 6                       0.13
# 7                       0.40
# 8                       2.38
# 9                       0.10
# 10                      0.40
# 11                      0.20
# 12                      2.38
# 13                      0.40
# 14                      3.17
# 15                      2.77
# 16                      2.77
# 17                      0.40
# 18                      3.17
# 19                      2.77
# 20                      2.38
# 21                      6.34
# 22                      0.79
# 23                      0.79
# 24                      1.19
# 25                      0.40
# 26                      0.26
# 27                      1.19
# 28                      2.38
# 29                      3.17
# ...                      ...
# 26896                   0.59
# 26897                   0.40
# 26898                   2.77
# 26899                   0.59
# 26900                   0.32
# 26901                   0.79
# 26902                   0.99
# 26903                   0.30
# 26904                   2.77
# 26905                   0.20
# 26906                   2.77
# 26907                   2.38
# 26908                   3.17
# 26909                   2.38
# 26910                   3.17
# 26911                   0.79
# 26912                   0.20
# 26913                   2.77
# 26914                   2.38
# 26915                   2.38
# 26916                   0.50
# 26917                   2.38
# 26918                   0.11
# 26919                   0.59
# 26920                   2.77
# 26921                   0.79
# 26922                   0.59
# 26923                   0.79
# 26924                   0.26
# 26925                   0.40
#
# [26926 rows x 18 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# There are many valid solutions.

# For the numerical variables
for column in ["Bottle Volume (ml)", "State Bottle Cost", "State Bottle Retail", "Bottles Sold", "Volume Sold (Liters)", "Volume Sold (Gallons)"]:
    new_sample.plot.scatter(x=column, y="Sale (Dollars)")

# %%
total_sales = new_sample['Sale (Dollars)'].groupby([new_sample['County'], new_sample['City'], new_sample['Zip Code'], new_sample['Store Number']]).agg({'Sale (Dollars)':sum})
Top_Sales = total_sales.sort_values(by='Sale (Dollars)', ascending = False)
Top_Sales.head(20)
# Out:
#                                                      Sale (Dollars)
# County        City            Zip Code Store Number
# Polk          DES MOINES      50320    2633               115013.90
#                               50314    4829                94167.27
# Johnson       IOWA CITY       52240    2512                72921.68
# Linn          CEDAR RAPIDS    52402    3385                61341.33
# Polk          WINDSOR HEIGHTS 50311    3420                42084.24
# Scott         BETTENDORF      52722    3952                40734.11
# Linn          CEDAR RAPIDS    52401    3773                30997.83
# Johnson       CORALVILLE      52241    2670                30375.51
# Pottawattamie COUNCIL BLUFFS  51501    4312                27155.60
# Woodbury      SIOUX CITY      51106    3447                24903.06
# Johnson       CORALVILLE      52241    4677                24354.32
# Polk          WEST DES MOINES 50265    2648                23812.66
# Black Hawk    WATERLOO        50703    2130                22503.00
# Carroll       CARROLL         51401    2593                22420.81
# Woodbury      SIOUX CITY      51103    3820                21895.04
# Dubuque       DUBUQUE         52001    4167                21370.47
# Scott         DAVENPORT       52807    3354                20395.50
# Linn          MOUNT VERNON    52314    5102                20373.06
# Scott         DAVENPORT       52807    2614                19747.04
# Dubuque       DUBUQUE         52001    2524                19107.53

# %%
Top_counties = pd.pivot_table(new_sample, index = ['County'], values = ['Sale (Dollars)'], aggfunc = sum)

# %%
Top10_Sales_County = Top_counties
Top10_Sales_by_County = Top10_Sales_County.sort('Sale (Dollars)', ascending = False).head(10)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %%
plt.figure(figsize=(15,10))
sns.barplot(y=Top10_Sales_by_County.index, x=Top10_Sales_by_County['Sale (Dollars)'], color='g')\
.set_title('Sale (Dollars) vs County')

# %%
Top_cities = pd.pivot_table(new_sample, index = ['City'], values = ['Sale (Dollars)'], aggfunc = sum)

# %%
Top20_Sales_City = Top_cities
Top20_Sales_by_City = Top20_Sales_City.sort('Sale (Dollars)', ascending = False).head(20)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %%
plt.figure(figsize=(20,30))
sns.barplot(y=Top20_Sales_by_City.index, x=Top20_Sales_by_City['Sale (Dollars)'], color='b')\
.set_title('Sale (Dollars) vs City')

# %% [markdown]
# ### State the risks and assumptions of your data (Outside considerations that could skew or affect the data and make it not reliable)

# %% [markdown]
# There are many risks and assumptions that could affect or contribute to making this data unreliable. For example, I removed all the rows with NaN values in them assuming that they were not relevant, but by doing so, I reduced the original dataset. Another thing that I did was that I took a 10% sample of the dataset in order to better work with it. This could skew the data in any direction, meaning that some counties would appear higher although they might not be in the original dataset.

# %% [markdown]
# # Mine the data
# Now you are ready to compute the variables you will use for your regression from the data. For example, you may want to
# compute total sales per store from Jan to March of 2015, mean price per bottle, etc. Refer to the readme for more ideas appropriate to your scenario.
#
# Pandas is your friend for this task. Take a look at the operations [here](http://pandas.pydata.org/pandas-docs/stable/groupby.html) for ideas on how to make the best use of pandas and feel free to search for blog and Stack Overflow posts to help you group data by certain variables and compute sums, means, etc. You may find it useful to create a new data frame to house this summary data.

# %% [markdown]
# ### Create necessary derived columns from the data (i.e. creating new metrics like bottle per month, finding relationships between columns, daily average user/bottles per person/bottle per store)

# %%
# Remove redundant columns
del new_sample["Category Name"]
del new_sample["Item Number"]
del new_sample["County Number"]

# %%
new_sample
# Out:
#              Date  Store Number             City Zip Code         County  \
# 0      2015-07-27          4794       BURLINGTON    52601     Des Moines
# 1      2015-01-27          4485          SANBORN    51248        O'Brien
# 2      2016-01-25          5095      CARTER LAKE    51510  Pottawattamie
# 3      2015-03-10          4167          DUBUQUE    52001        Dubuque
# 4      2015-09-22          2619  WEST DES MOINES    50266           Polk
# 5      2015-12-03          4686          CLINTON    52732        Clinton
# 6      2015-12-01          3443   COUNCIL BLUFFS    51503  Pottawattamie
# 7      2015-11-30          2538         WATERLOO    50702     Black Hawk
# 8      2015-05-27          3825       DES MOINES    50316           Polk
# 9      2016-03-08          5176     CEDAR RAPIDS    52405           Linn
# 10     2016-01-05          4485          SANBORN    51248        O'Brien
# 11     2015-01-12          2478          ALTOONA    50009           Polk
# 12     2015-09-10          2663        URBANDALE    50322           Polk
# 13     2015-11-09          2670       CORALVILLE    52241        Johnson
# 14     2015-11-17          4592       EMMETSBURG    50536      Palo Alto
# 15     2015-12-07          3525       WASHINGTON    52353     Washington
# 16     2015-01-20          3704       EMMETSBURG    50536      Palo Alto
# 17     2015-11-03          4310         CHEROKEE    51012       Cherokee
# 18     2015-12-30          2515       MASON CITY    50401    Cerro Gordo
# 19     2015-01-21          3584          OELWEIN    50662        Fayette
# 20     2015-09-08          3738          DUBUQUE    52001        Dubuque
# 21     2015-06-01          3952       BETTENDORF    52722          Scott
# 22     2015-01-22          4091       CLEAR LAKE    50428    Cerro Gordo
# 23     2015-10-13          4904        LARCHWOOD    51241           Lyon
# 24     2015-06-10          4437             AMES    50010          Story
# 25     2016-03-03          5196       CORALVILLE    52241        Johnson
# 26     2015-01-20          4291          CRESTON    50801          Union
# 27     2015-02-19          5069       LAKE MILLS    50450      Winnebago
# 28     2015-08-19          3820       SIOUX CITY    51103       Woodbury
# 29     2015-11-23          2585           ALGONA    50511        Kossuth
# ...           ...           ...              ...      ...            ...
# 26896  2015-06-24          3778       DES MOINES    50310           Polk
# 26897  2016-02-29          4604           NEWTON    50208         Jasper
# 26898  2015-04-30          2806          CLINTON    52732        Clinton
# 26899  2015-10-01          3858        DAVENPORT    52806          Scott
# 26900  2015-06-24          4568       SIOUX CITY    51108       Woodbury
# 26901  2015-08-05          2545        IOWA CITY    52245        Johnson
# 26902  2016-03-01          4448        URBANDALE    50322           Polk
# 26903  2015-05-28          4345         GRINNELL    50112      Poweshiek
# 26904  2015-11-20          3162        MUSCATINE    52761      Muscatine
# 26905  2015-11-24          5106           DEWITT    52742        Clinton
# 26906  2016-03-22          2619  WEST DES MOINES    50266           Polk
# 26907  2016-02-01          3899  WEST DES MOINES    50266           Polk
# 26908  2015-05-22          3952       BETTENDORF    52722          Scott
# 26909  2015-01-26          4580       WASHINGTON    52353     Washington
# 26910  2015-06-17          3773     CEDAR RAPIDS    52401           Linn
# 26911  2015-05-27          5057       DES MOINES    50317           Polk
# 26912  2016-03-02          3762  WINDSOR HEIGHTS    50322           Polk
# 26913  2015-05-05          2665           WAUKEE    50263         Dallas
# 26914  2015-08-12          2501             AMES    50010          Story
# 26915  2016-01-05          3981     SIOUX CENTER    51250          Sioux
# 26916  2015-07-27          5149       BURLINGTON    52601     Des Moines
# 26917  2015-04-29          3776        DAVENPORT    52806          Scott
# 26918  2016-03-21          2647     CEDAR RAPIDS    52411           Linn
# 26919  2015-08-03          4125          WAPELLO    52653         Louisa
# 26920  2015-06-30          4116        LAKE VIEW    51450            Sac
# 26921  2015-05-06          2625        DAVENPORT    52804          Scott
# 26922  2016-03-14          2569     CEDAR RAPIDS    52402           Linn
# 26923  2015-04-16          4864          CLINTON    52733        Clinton
# 26924  2015-04-15          3943           NEVADA    50201          Story
# 26925  2015-04-30          4969       CLEAR LAKE    50428    Cerro Gordo
#
#         Category  Vendor Number                            Item Description  \
# 0      1032080.0             35                            Grey Goose Vodka
# 1      1081200.0            330                        Ryan's Cream Liqueur
# 2      1081600.0            421    Fireball Cinnamon Whiskey Mini Dispenser
# 3      1012200.0             55                                    Lauder's
# 4      1051010.0            115                  Paul Masson Vs Brandy Mini
# 5      1051010.0            205                             E & J Vs Brandy
# 6      1062310.0            259              Admiral Nelson Spiced Rum Mini
# 7      1032080.0            962                                 Medea Vodka
# 8      1031200.0            205                     New Amsterdam Pineapple
# 9      1032200.0            260                             Ciroc Pineapple
# 10     1011500.0            255                               Templeton Rye
# 11     1012200.0            260                        Johnnie Walker Black
# 12     1041100.0             65                     Gilbey's Gin London Dry
# 13     1082900.0            389                                 Metaxa Ouzo
# 14     1012100.0            115                                Black Velvet
# 15     1031080.0            297                          Five O'clock Vodka
# 16     1031080.0            297                          Five O'clock Vodka
# 17     1012200.0             55                             Lauder's Scotch
# 18     1062200.0             35                        Bacardi Superior Rum
# 19     1062310.0            260                Captain Morgan Spiced Barrel
# 20     1031080.0             55                                  Skol Vodka
# 21     1062200.0            297                                Five O'clock
# 22     1041100.0            370                      Seagrams Extra Dry Gin
# 23     1031200.0            260                     Jeremiah Weed Sweet Tea
# 24     1012100.0            115                Black Velvet Toasted Caramel
# 25     1031080.0            205                         New Amsterdam Vodka
# 26     1062200.0             35                            Bacardi Gold Rum
# 27     1011200.0             65                      Jim Beam Kentucky Fire
# 28     1062300.0             65                            Cruzan Mango Rum
# 29     1081600.0            421                   Fireball Cinnamon Whiskey
# ...          ...            ...                                         ...
# 26896  1031200.0            205                     New Amsterdam Pineapple
# 26897  1051010.0            205                                    E & J Vs
# 26898  1071100.0            395  Jose Cuervo Authentic Watermelon Margarita
# 26899  1012200.0             55                    Lauder's Scotch Traveler
# 26900  1012100.0            260                Crown Royal Regal Apple Mini
# 26901  1011100.0             65                    Beam's 8 Star Bl Whiskey
# 26902  1031080.0            434                               Hawkeye Vodka
# 26903  1081300.0            434               Paramount Peppermint Schnapps
# 26904  1081300.0            434                   Arrow Peppermint Schnapps
# 26905  1012210.0             65          Laphroaig 10 Yr Single Malt Scotch
# 26906  1042100.0            260                               Tanqueray Gin
# 26907  1011100.0            260                 Seagrams 7 Crown Bl Whiskey
# 26908  1032200.0            277            Stolichnaya Vanil Vodka 75 Proof
# 26909  1031080.0            297                          Five O'clock Vodka
# 26910  1081700.0            434                             Juarez Gold Dss
# 26911  1081600.0            421    Fireball Cinnamon Whiskey Mini Dispenser
# 26912  1011200.0             85                    Woodford Reserve Bourbon
# 26913  1012200.0             55                                    Lauder's
# 26914  1031080.0            380                              Phillips Vodka
# 26915  1012200.0            260              Buchanan's 12 Yr Deluxe Scotch
# 26916  1012100.0            115                                Black Velvet
# 26917  1031200.0            260                         Smirnoff Strawberry
# 26918  1031080.0            260                       Smirnoff Vodka 80 Prf
# 26919  1031200.0            255          Seagram's Red Berry Flavored Vodka
# 26920  1071100.0             55                 Chi-Chi's Pina Colada W/rum
# 26921  1011200.0            259                   Evan Williams Str Bourbon
# 26922  1062310.0            395                     Kraken Black Spiced Rum
# 26923  1012100.0            260            Crown Royal Canadian Whisky Mini
# 26924  1032080.0            370                Absolut Swedish Vodka 80 Prf
# 26925  1082900.0             55                        Caravella Limoncello
#
#        Bottle Volume (ml)  State Bottle Cost  State Bottle Retail  \
# 0                  1750.0              35.42                53.13
# 1                  1000.0               7.23                10.85
# 2                  3000.0              29.72                44.58
# 3                  1000.0               6.14                 9.21
# 4                   600.0               7.12                10.68
# 5                   375.0               3.22                 4.83
# 6                   500.0               3.78                 5.67
# 7                   750.0              18.84                28.26
# 8                   375.0               3.50                 5.25
# 9                   375.0               9.25                13.88
# 10                  750.0              18.09                27.14
# 11                  750.0              20.75                31.13
# 12                  750.0               4.72                 7.08
# 13                  750.0              10.50                15.75
# 14                 1000.0               6.63                 9.95
# 15                 1750.0               7.20                10.80
# 16                 1750.0               7.20                10.80
# 17                  750.0               5.13                 7.70
# 18                 1000.0               9.50                14.25
# 19                 1750.0              18.00                27.00
# 20                  750.0               3.64                 5.46
# 21                 1000.0               4.37                 6.56
# 22                  750.0               6.49                 9.74
# 23                 1000.0              10.50                15.75
# 24                  750.0               6.75                10.13
# 25                  750.0               6.90                10.35
# 26                 1000.0               9.50                14.25
# 27                  750.0              11.03                16.55
# 28                  750.0               6.83                10.25
# 29                 1000.0              11.34                17.01
# ...                   ...                ...                  ...
# 26896               375.0               3.50                 5.25
# 26897               750.0               6.00                 9.00
# 26898              1750.0               8.20                12.30
# 26899               750.0               4.63                 7.20
# 26900               300.0               7.35                11.03
# 26901               750.0               3.67                 5.51
# 26902               375.0               1.86                 2.79
# 26903               375.0               2.28                 3.42
# 26904              1750.0               7.05                10.58
# 26905               750.0              26.24                39.36
# 26906              1750.0              24.99                37.49
# 26907               750.0               7.00                10.50
# 26908              1000.0              15.97                23.96
# 26909               375.0               1.93                 2.90
# 26910              1000.0               4.92                 7.38
# 26911              3000.0              29.72                44.58
# 26912               750.0              21.02                31.53
# 26913              1750.0              10.68                16.27
# 26914               750.0               3.57                 5.36
# 26915               750.0              21.99                32.99
# 26916               375.0               3.07                 4.61
# 26917               750.0               8.25                12.38
# 26918               200.0               2.54                 3.81
# 26919               750.0               5.38                 8.07
# 26920              1750.0               6.00                 9.25
# 26921               750.0               6.81                10.55
# 26922               750.0              10.00                15.00
# 26923               300.0               7.35                11.03
# 26924              1000.0              14.99                22.49
# 26925               750.0              11.25                16.88
#
#        Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 0                 2          106.26                  3.50
# 1                 3           32.55                  3.00
# 2                 8          356.64                 24.00
# 3                12          110.52                 12.00
# 4                 1           10.68                  0.60
# 5                 2            9.66                  0.75
# 6                 1            5.67                  0.50
# 7                 2           56.52                  1.50
# 8                24          126.00                  9.00
# 9                 1           13.88                  0.38
# 10                2           54.28                  1.50
# 11                1           31.13                  0.75
# 12               12           84.96                  9.00
# 13                2           31.50                  1.50
# 14               12          119.40                 12.00
# 15                6           64.80                 10.50
# 16                6           64.80                 10.50
# 17                2           15.40                  1.50
# 18               12          171.00                 12.00
# 19                6          162.00                 10.50
# 20               12           65.52                  9.00
# 21               24          157.44                 24.00
# 22                4           38.96                  3.00
# 23                3           47.25                  3.00
# 24                6           60.78                  4.50
# 25                2           20.70                  1.50
# 26                1           14.25                  1.00
# 27                6           99.30                  4.50
# 28               12          123.00                  9.00
# 29               12          204.12                 12.00
# ...             ...             ...                   ...
# 26896             6           31.50                  2.25
# 26897             2           18.00                  1.50
# 26898             6           73.80                 10.50
# 26899             3           21.60                  2.25
# 26900             4           44.12                  1.20
# 26901             4           22.04                  3.00
# 26902            10           27.90                  3.75
# 26903             3           10.26                  1.12
# 26904             6           63.48                 10.50
# 26905             1           39.36                  0.75
# 26906             6          224.94                 10.50
# 26907            12          126.00                  9.00
# 26908            12          287.52                 12.00
# 26909            24           69.60                  9.00
# 26910            12           88.56                 12.00
# 26911             1           44.58                  3.00
# 26912             1           31.53                  0.75
# 26913             6           97.62                 10.50
# 26914            12           64.32                  9.00
# 26915            12          395.88                  9.00
# 26916             5           23.05                  1.88
# 26917            12          148.56                  9.00
# 26918             2            7.62                  0.40
# 26919             3           24.21                  2.25
# 26920             6           55.50                 10.50
# 26921             4           42.20                  3.00
# 26922             3           45.00                  2.25
# 26923            10          110.30                  3.00
# 26924             1           22.49                  1.00
# 26925             2           33.76                  1.50
#
#        Volume Sold (Gallons)
# 0                       0.92
# 1                       0.79
# 2                       6.34
# 3                       3.17
# 4                       0.16
# 5                       0.20
# 6                       0.13
# 7                       0.40
# 8                       2.38
# 9                       0.10
# 10                      0.40
# 11                      0.20
# 12                      2.38
# 13                      0.40
# 14                      3.17
# 15                      2.77
# 16                      2.77
# 17                      0.40
# 18                      3.17
# 19                      2.77
# 20                      2.38
# 21                      6.34
# 22                      0.79
# 23                      0.79
# 24                      1.19
# 25                      0.40
# 26                      0.26
# 27                      1.19
# 28                      2.38
# 29                      3.17
# ...                      ...
# 26896                   0.59
# 26897                   0.40
# 26898                   2.77
# 26899                   0.59
# 26900                   0.32
# 26901                   0.79
# 26902                   0.99
# 26903                   0.30
# 26904                   2.77
# 26905                   0.20
# 26906                   2.77
# 26907                   2.38
# 26908                   3.17
# 26909                   2.38
# 26910                   3.17
# 26911                   0.79
# 26912                   0.20
# 26913                   2.77
# 26914                   2.38
# 26915                   2.38
# 26916                   0.50
# 26917                   2.38
# 26918                   0.11
# 26919                   0.59
# 26920                   2.77
# 26921                   0.79
# 26922                   0.59
# 26923                   0.79
# 26924                   0.26
# 26925                   0.40
#
# [26926 rows x 15 columns]

# %% [markdown]
# ### Format, clean, slice, and combine the data in Python (Put everything together)

# %% [markdown]
# Note: Most of the cleaning was done previously in the Explore the Data section under "Perform exploratory analysis and visualizations"

# %%
new_sample.dtypes
# Out:
# Date                      object
# Store Number               int64
# City                      object
# Zip Code                  object
# County                    object
# Category                 float64
# Vendor Number              int64
# Item Description          object
# Bottle Volume (ml)       float64
# State Bottle Cost        float64
# State Bottle Retail      float64
# Bottles Sold               int64
# Sale (Dollars)           float64
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtype: object

# %%
new_sample['Date'] = pd.to_datetime(new_sample['Date'], format ="%Y/%m/%d")

# %%
# Determine which stores were open all of 2015
# Find the first and last sales date.
dates = new_sample.groupby(by=["Store Number"], as_index=False)
dates = dates.agg({"Date": [np.min, np.max]})
dates.columns = [' '.join(col).strip() for col in dates.columns.values]
dates.head()

# Filter out stores that opened or closed throughout the year
# You may want to save this step until you start modelling
lower_cutoff = pd.Timestamp("20150101")
upper_cutoff = pd.Timestamp("20151231")
mask = (dates['Date amin'] >= lower_cutoff) & (dates['Date amax'] <= upper_cutoff)
good_stores = dates[mask]["Store Number"]
new_sample1 = new_sample[new_sample["Store Number"].isin(good_stores)]

# %%
new_sample1
# Out:
#             Date  Store Number            City Zip Code         County  \
# 5     2015-12-03          4686         CLINTON    52732        Clinton
# 17    2015-11-03          4310        CHEROKEE    51012       Cherokee
# 27    2015-02-19          5069      LAKE MILLS    50450      Winnebago
# 32    2015-07-06          3631         AUDUBON    50025        Audubon
# 35    2015-05-04          2514          MARION    50129           Linn
# 88    2015-08-03          4307          DUNLAP    712-2       Harrison
# 95    2015-05-19          4626  COUNCIL BLUFFS    51501  Pottawattamie
# 105   2015-01-29          2838       DAVENPORT    52806          Scott
# 128   2015-06-02          4195          TOLEDO    52342           Tama
# 134   2015-11-19          4511      DES MOINES    50317           Polk
# 135   2015-06-03          4762   FORT ATKINSON    52144     Winneshiek
# 168   2015-12-16          5135          HUXLEY    50124          Story
# 177   2015-02-12          5038        WATERLOO    50701     Black Hawk
# 181   2015-06-15          3611           LOGAN    51546       Harrison
# 212   2015-06-17          4192      BETTENDORF    52722          Scott
# 244   2015-01-07          4107           BOONE    50036          Boone
# 262   2015-02-09          2514          MARION    50129           Linn
# 264   2015-01-13          3529        CHEROKEE    51012       Cherokee
# 275   2015-06-09          4533       ST ANSGAR    50472       Mitchell
# 282   2015-03-09          2487         ANAMOSA    52205          Jones
# 294   2015-03-25          4356          NEVADA    50201          Story
# 299   2015-06-22          4612       DAVENPORT    52802          Scott
# 308   2015-10-20          4926      DES MOINES    50322           Polk
# 351   2015-11-18          4737      STORM LAKE    50588    Buena Vista
# 399   2015-10-08          4881     COON RAPIDS    50058        Carroll
# 405   2015-06-01          4869      GUTTENBERG    52052        Clayton
# 412   2015-11-30          2847          MARION    52302           Linn
# 417   2015-02-19          5079         DENISON    51442       Crawford
# 427   2015-05-27          4681      WEST UNION    52175        Fayette
# 435   2015-11-17          4643         RED OAK    51566     Montgomery
# ...          ...           ...             ...      ...            ...
# 26507 2015-09-22          4909     ROCK VALLEY    51247          Sioux
# 26537 2015-09-30          3973            AMES    50014          Story
# 26544 2015-07-06          4283          MARION    52302           Linn
# 26545 2015-01-13          4450       URBANDALE    50323           Polk
# 26551 2015-03-19          5093       LE CLAIRE    52753          Scott
# 26566 2015-03-05          2954      DES MOINES    50300           Polk
# 26578 2015-05-13          4860    CEDAR RAPIDS    52404           Linn
# 26587 2015-01-13          4322          BAXTER    50028         Jasper
# 26617 2015-01-13          4006       LARCHWOOD    51241           Lyon
# 26642 2015-06-02          4920        JOHNSTON    50131           Polk
# 26649 2015-01-22          3692       MT VERNON    52314           Linn
# 26661 2015-02-12          2962        JOHNSTON    50131           Polk
# 26667 2015-02-16          2460         HAMPTON    50441       Franklin
# 26674 2015-12-29          4750       DAVENPORT    52807          Scott
# 26727 2015-12-16          4275       KNOXVILLE    50138         Marion
# 26734 2015-05-04          2460         HAMPTON    50441       Franklin
# 26751 2015-04-29          4432      CORALVILLE    52241        Johnson
# 26763 2015-07-30          4521  GRAND JUNCTION    50107         Greene
# 26769 2015-09-01          2205        CLARINDA    51632           Page
# 26778 2015-06-02          2367      SHENANDOAH    51601           Page
# 26800 2015-02-25          4681      WEST UNION    52175        Fayette
# 26803 2015-02-17          4488    CEDAR RAPIDS    52404           Linn
# 26814 2015-09-23          4107           BOONE    50036          Boone
# 26816 2015-07-07          4434     ROCK RAPIDS    51246           Lyon
# 26820 2015-05-14          4882      ST CHARLES    50240        Madison
# 26821 2015-09-28          2487         ANAMOSA    52205          Jones
# 26824 2015-05-18          5074    CEDAR RAPIDS    52402           Linn
# 26832 2015-12-01          4535         DUBUQUE    52001        Dubuque
# 26886 2015-10-29          4360          NEWTON    50208         Jasper
# 26891 2015-10-06          3849      DYERSVILLE    52040        Dubuque
#
#         Category  Vendor Number                     Item Description  \
# 5      1051010.0            205                      E & J Vs Brandy
# 17     1012200.0             55                      Lauder's Scotch
# 27     1011200.0             65               Jim Beam Kentucky Fire
# 32     1081900.0            434               Paramount Blue Curacao
# 35     1032080.0            434                      Pearl Vodka PET
# 88     1012100.0            434              Canadian Reserve Whisky
# 95     1041100.0            370          Seagrams Extra Dry Gin Mini
# 105    1062200.0            434                  Paramount White Rum
# 128    1011200.0            259            Evan Williams Str Bourbon
# 134    1031100.0            260               Smirnoff Vodka 100 Prf
# 135    1031080.0            434                        Hawkeye Vodka
# 168    1062200.0             35                 Bacardi Superior Rum
# 177    1052010.0            389              Remy Martin Vsop Cognac
# 181    1031080.0            434                        Hawkeye Vodka
# 212    1081200.0            322                               Ricura
# 244    1012200.0             55                             Lauder's
# 262    1012100.0             85       Canadian Mist Canadian Why Pet
# 264    1062300.0            370                   Malibu Coconut Rum
# 275    1032080.0            370         Absolut Swedish Vodka 80 Prf
# 282    1081600.0             85                 Southern Comfort PET
# 294    1081200.0            305                             Rumchata
# 299    1051010.0            205                      E & J Vs Brandy
# 308    1041100.0            370               Seagrams Extra Dry Gin
# 351    1081030.0            370                Kahlua Coffee Liqueur
# 399    1062200.0             35                 Bacardi Superior Rum
# 405    1012100.0            115                         Black Velvet
# 412    1031080.0             55                           Skol Vodka
# 417    1011100.0            260          Seagrams 7 Crown Bl Whiskey
# 427    1062200.0             35                 Bacardi Superior Rum
# 435    1062310.0            260       Captain Morgan Spiced Rum Mini
# ...          ...            ...                                  ...
# 26507  1012100.0            115                         Black Velvet
# 26537  1081400.0             55                 Montezuma Triple Sec
# 26544  1031200.0            259                 Burnett's Watermelon
# 26545  1011200.0             65                             Jim Beam
# 26551  1052010.0            420                          Hennessy VS
# 26566  1081030.0            370                Kahlua Coffee Liqueur
# 26578  1011200.0             65                             Jim Beam
# 26587  1012100.0            115         Black Velvet Toasted Caramel
# 26617  1082900.0            192                 Jagermeister Liqueur
# 26642  1081600.0            421            Fireball Cinnamon Whiskey
# 26649  1012100.0            115                         Black Velvet
# 26661  1062300.0             35                 Bacardi Mango Fusion
# 26667  1062200.0             35                   Bacardi Select Rum
# 26674  1081200.0            260        Bailey's Original Irish Cream
# 26727  1081200.0            305                             Rumchata
# 26734  1012100.0            115                Black Velvet Traveler
# 26751  1022100.0            395  Jose Cuervo Especial Reposado Flask
# 26763  1012100.0            115                         Black Velvet
# 26769  1012100.0            260     Crown Royal Canadian Whisky Mini
# 26778  1011300.0             85                       Gentleman Jack
# 26800  1081200.0            260        Bailey's Original Irish Cream
# 26803  1031080.0            260                Smirnoff Vodka 80 Prf
# 26814  1062200.0            434                  Paramount White Rum
# 26816  1011300.0             85        Jack Daniels Old #7 Black Lbl
# 26820  1012100.0            115                         Black Velvet
# 26821  1031080.0            434                        Hawkeye Vodka
# 26824  1011500.0            125               Cedar Ridge Malted Rye
# 26832  1031080.0            434                        Hawkeye Vodka
# 26886  1041100.0            370          Seagrams Extra Dry Gin Mini
# 26891  1031080.0            434                        Hawkeye Vodka
#
#        Bottle Volume (ml)  State Bottle Cost  State Bottle Retail  \
# 5                   375.0               3.22                 4.83
# 17                  750.0               5.13                 7.70
# 27                  750.0              11.03                16.55
# 32                  750.0               4.75                 7.13
# 35                 1750.0              10.00                15.00
# 88                 1750.0               9.00                13.50
# 95                  500.0               3.30                 4.95
# 105                1750.0               7.84                11.76
# 128                 750.0               7.47                11.21
# 134                 750.0               9.50                14.25
# 135                1000.0               4.05                 6.08
# 168                1750.0              15.00                22.50
# 177                 200.0               5.42                 8.13
# 181                 750.0               3.34                 5.01
# 212                 750.0              10.00                15.00
# 244                1750.0              11.18                16.77
# 262                1750.0              10.50                15.75
# 264                1000.0              10.49                15.74
# 275                 750.0              11.49                17.24
# 282                1750.0              19.16                28.74
# 294                 750.0              12.50                18.75
# 299                 200.0               1.96                 2.94
# 308                 375.0               3.39                 5.09
# 351                 750.0              11.99                17.99
# 399                1750.0              15.00                22.50
# 405                1000.0               6.63                 9.95
# 412                1750.0               7.11                10.67
# 417                 375.0               3.50                 5.25
# 427                1000.0               9.50                14.25
# 435                 500.0               4.80                 7.20
# ...                   ...                ...                  ...
# 26507              1000.0               6.63                 9.95
# 26537              1000.0               2.13                 3.20
# 26544               750.0               4.84                 7.26
# 26545               375.0               4.76                 7.14
# 26551               375.0               9.99                14.99
# 26566               750.0              11.99                17.99
# 26578              1000.0              12.59                18.89
# 26587               750.0               6.75                10.13
# 26617              1000.0              15.54                23.31
# 26642               750.0               8.98                13.47
# 26649               375.0               3.07                 4.61
# 26661               750.0               7.75                12.00
# 26667              1750.0              15.00                22.50
# 26674               750.0              13.49                20.24
# 26727               750.0              12.50                18.75
# 26734               750.0               5.23                 7.85
# 26751               375.0               5.50                 8.25
# 26763              1750.0               9.70                14.93
# 26769               300.0               7.35                11.03
# 26778               750.0              20.01                30.02
# 26800              1000.0              17.25                25.88
# 26803               750.0               8.25                12.38
# 26814               750.0               4.00                 6.00
# 26816               750.0              15.07                22.61
# 26820              1750.0               9.70                14.93
# 26821               200.0               1.15                 1.73
# 26824               750.0              19.67                29.51
# 26832              1750.0               7.17                10.76
# 26886               500.0               3.30                 4.95
# 26891              1000.0               4.05                 6.08
#
#        Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 5                 2            9.66                  0.75
# 17                2           15.40                  1.50
# 27                6           99.30                  4.50
# 32                2           14.26                  1.50
# 35                6           90.00                 10.50
# 88                6           81.00                 10.50
# 95                1            4.95                  0.50
# 105               6           70.56                 10.50
# 128               2           22.42                  1.50
# 134              12          171.00                  9.00
# 135              12           72.96                 12.00
# 168               6          135.00                 10.50
# 177               4           32.52                  0.80
# 181              12           60.12                  9.00
# 212               6           90.00                  4.50
# 244               1           16.77                  1.75
# 262               2           31.50                  3.50
# 264               3           47.22                  3.00
# 275              12          206.88                  9.00
# 282               1           28.74                  1.75
# 294               6          112.50                  4.50
# 299              24           70.56                  4.80
# 308               4           20.36                  1.50
# 351              12          215.88                  9.00
# 399               6          135.00                 10.50
# 405              12          119.40                 12.00
# 412               6           64.02                 10.50
# 417               3           15.75                  1.12
# 427               4           57.00                  4.00
# 435               6           43.20                  3.00
# ...             ...             ...                   ...
# 26507            12          119.40                 12.00
# 26537            12           38.40                 12.00
# 26544             3           21.78                  2.25
# 26545             4           28.56                  1.50
# 26551             4           59.96                  1.50
# 26566             4           71.96                  3.00
# 26578             1           18.89                  1.00
# 26587             1           10.13                  0.75
# 26617            12          279.72                 12.00
# 26642            12          161.64                  9.00
# 26649            24          110.64                  9.00
# 26661             3           36.00                  2.25
# 26667            12          270.00                 21.00
# 26674            12          242.88                  9.00
# 26727            12          225.00                  9.00
# 26734            12           94.20                  9.00
# 26751             8           66.00                  3.00
# 26763            12          179.16                 21.00
# 26769             1           11.03                  0.30
# 26778             3           90.06                  2.25
# 26800             2           51.76                  2.00
# 26803             6           74.28                  4.50
# 26814            12           72.00                  9.00
# 26816             5          113.05                  3.75
# 26820            18          268.74                 31.50
# 26821             3            5.19                  0.60
# 26824             6          177.06                  4.50
# 26832            18          193.68                 31.50
# 26886            24          118.80                 12.00
# 26891            12           72.96                 12.00
#
#        Volume Sold (Gallons)
# 5                       0.20
# 17                      0.40
# 27                      1.19
# 32                      0.40
# 35                      2.77
# 88                      2.77
# 95                      0.13
# 105                     2.77
# 128                     0.40
# 134                     2.38
# 135                     3.17
# 168                     2.77
# 177                     0.21
# 181                     2.38
# 212                     1.19
# 244                     0.46
# 262                     0.92
# 264                     0.79
# 275                     2.38
# 282                     0.46
# 294                     1.19
# 299                     1.27
# 308                     0.40
# 351                     2.38
# 399                     2.77
# 405                     3.17
# 412                     2.77
# 417                     0.30
# 427                     1.06
# 435                     0.79
# ...                      ...
# 26507                   3.17
# 26537                   3.17
# 26544                   0.59
# 26545                   0.40
# 26551                   0.40
# 26566                   0.79
# 26578                   0.26
# 26587                   0.20
# 26617                   3.17
# 26642                   2.38
# 26649                   2.38
# 26661                   0.59
# 26667                   5.55
# 26674                   2.38
# 26727                   2.38
# 26734                   2.38
# 26751                   0.79
# 26763                   5.55
# 26769                   0.08
# 26778                   0.59
# 26800                   0.53
# 26803                   1.19
# 26814                   2.38
# 26816                   0.99
# 26820                   8.32
# 26821                   0.16
# 26824                   1.19
# 26832                   8.32
# 26886                   3.17
# 26891                   3.17
#
# [1627 rows x 15 columns]

# %%
# Margin
new_sample["Margin"] = (new_sample["State Bottle Retail"] - new_sample["State Bottle Cost"]) * new_sample["Bottles Sold"]
new_sample["Price per Liter"] = new_sample["Sale (Dollars)"] / new_sample["Volume Sold (Liters)"]
new_sample.head()
# Out:
#         Date  Store Number             City Zip Code         County  \
# 0 2015-07-27          4794       BURLINGTON    52601     Des Moines
# 1 2015-01-27          4485          SANBORN    51248        O'Brien
# 2 2016-01-25          5095      CARTER LAKE    51510  Pottawattamie
# 3 2015-03-10          4167          DUBUQUE    52001        Dubuque
# 4 2015-09-22          2619  WEST DES MOINES    50266           Polk
#
#     Category  Vendor Number                          Item Description  \
# 0  1032080.0             35                          Grey Goose Vodka
# 1  1081200.0            330                      Ryan's Cream Liqueur
# 2  1081600.0            421  Fireball Cinnamon Whiskey Mini Dispenser
# 3  1012200.0             55                                  Lauder's
# 4  1051010.0            115                Paul Masson Vs Brandy Mini
#
#    Bottle Volume (ml)  State Bottle Cost  State Bottle Retail  Bottles Sold  \
# 0              1750.0              35.42                53.13             2
# 1              1000.0               7.23                10.85             3
# 2              3000.0              29.72                44.58             8
# 3              1000.0               6.14                 9.21            12
# 4               600.0               7.12                10.68             1
#
#    Sale (Dollars)  Volume Sold (Liters)  Volume Sold (Gallons)  Margin  \
# 0          106.26                   3.5                   0.92   35.42
# 1           32.55                   3.0                   0.79   10.86
# 2          356.64                  24.0                   6.34  118.88
# 3          110.52                  12.0                   3.17   36.84
# 4           10.68                   0.6                   0.16    3.56
#
#    Price per Liter
# 0            30.36
# 1            10.85
# 2            14.86
# 3             9.21
# 4            17.80

# %%
# Sales per store, 2015

# Filter by our start and end dates
new_sample.sort_values(by=["Store Number", "Date"], inplace=True)
start_date = pd.Timestamp("20150101")
end_date = pd.Timestamp("20151231")
mask = (new_sample['Date'] >= start_date) & (new_sample['Date'] <= end_date)
sales = new_sample[mask]

# Group by store name
sales = sales.groupby(by=["Store Number"], as_index=False)
# Compute sums, means
sales = sales.agg({"Sale (Dollars)": [np.sum, np.mean],
                   "Volume Sold (Liters)": [np.sum, np.mean],
                   "Margin": np.mean,
                   "Price per Liter": np.mean,
                   "Zip Code": lambda x: x.iloc[0], # just extract once, should be the same
                   "City": lambda x: x.iloc[0],
                   "County": lambda x: x.iloc[0]})
# Collapse the column indices
sales.columns = [' '.join(col).strip() for col in sales.columns.values]
# Rename columns
sales.columns = [u'Store Number', u'City', u'2015 Sales',
       u'2015 Sales mean', 
       u'Price per Liter mean', u'Zip Code', u'County',
       u'2015 Volume Sold (Liters)', u'2015 Volume Sold (Liters) mean',
       u'2015 Margin mean']
# Quick check
sales.head()
# Out:
#    Store Number         City  2015 Sales  2015 Sales mean  \
# 0          2106  CEDAR FALLS    13719.10       311.797727
# 1          2113       GOWRIE      714.31        59.525833
# 2          2130     WATERLOO    19461.06       512.133158
# 3          2152     ROCKWELL     1273.23       106.102500
# 4          2178       WAUKON     1832.32        87.253333
#
#    Price per Liter mean Zip Code       County  2015 Volume Sold (Liters)  \
# 0             17.116255    50613   Black Hawk                     841.25
# 1             21.144167    50543      Webster                      44.25
# 2             18.515652    50703   Black Hawk                    1060.20
# 3             14.239444    50469  Cerro Gordo                      79.25
# 4             15.532918    52172    Allamakee                     154.86
#
#    2015 Volume Sold (Liters) mean  2015 Margin mean
# 0                       19.119318        104.096818
# 1                        3.687500         19.844167
# 2                       27.900000        170.772632
# 3                        6.604167         35.420833
# 4                        7.374286         29.391429

# %%
# Quick plot to check the computations
#plt.figure(figsize = (10,10))
sales.plot(kind='scatter', x="2015 Margin mean", y="2015 Volume Sold (Liters) mean");

plt.xlim(0, 1500)
plt.ylim(0, 200)
# Out:
# (0, 200)

# %% [markdown]
# # Refine the data
# Look for any statistical relationships, correlations, or other relevant properties of the dataset.

# %% [markdown]
# ### Determine outliers, skew distribution of important variables (if any) (scipy.stats.skew)

# %% [markdown]
# ### Determine correlations / causations in the data

# %%
new_sample.corr()
# Out:
#                        Store Number  Category  Vendor Number  \
# Store Number               1.000000 -0.013185      -0.001521
# Category                  -0.013185  1.000000       0.089677
# Vendor Number             -0.001521  0.089677       1.000000
# Bottle Volume (ml)        -0.067255 -0.016110       0.030081
# State Bottle Cost         -0.078224 -0.005695      -0.001323
# State Bottle Retail       -0.078330 -0.005913      -0.001637
# Bottles Sold               0.010448 -0.001671       0.003284
# Sale (Dollars)            -0.022477  0.009339      -0.002874
# Volume Sold (Liters)      -0.021218 -0.008392       0.001540
# Volume Sold (Gallons)     -0.021208 -0.008382       0.001544
# Margin                    -0.022401  0.009036      -0.003211
# Price per Liter           -0.016145 -0.003992       0.003605
#
#                        Bottle Volume (ml)  State Bottle Cost  \
# Store Number                    -0.067255          -0.078224
# Category                        -0.016110          -0.005695
# Vendor Number                    0.030081          -0.001323
# Bottle Volume (ml)               1.000000           0.331648
# State Bottle Cost                0.331648           1.000000
# State Bottle Retail              0.332543           0.999960
# Bottles Sold                    -0.018690          -0.068569
# Sale (Dollars)                   0.082994           0.144715
# Volume Sold (Liters)             0.159434           0.008386
# Volume Sold (Gallons)            0.159243           0.008352
# Margin                           0.083508           0.144026
# Price per Liter                 -0.315272           0.720462
#
#                        State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# Store Number                     -0.078330      0.010448       -0.022477
# Category                         -0.005913     -0.001671        0.009339
# Vendor Number                    -0.001637      0.003284       -0.002874
# Bottle Volume (ml)                0.332543     -0.018690        0.082994
# State Bottle Cost                 0.999960     -0.068569        0.144715
# State Bottle Retail               1.000000     -0.068491        0.144848
# Bottles Sold                     -0.068491      1.000000        0.839944
# Sale (Dollars)                    0.144848      0.839944        1.000000
# Volume Sold (Liters)              0.008741      0.905197        0.862246
# Volume Sold (Gallons)             0.008707      0.905233        0.862262
# Margin                            0.144205      0.840511        0.999845
# Price per Liter                   0.720010     -0.065646        0.066216
#
#                        Volume Sold (Liters)  Volume Sold (Gallons)    Margin  \
# Store Number                      -0.021218              -0.021208 -0.022401
# Category                          -0.008392              -0.008382  0.009036
# Vendor Number                      0.001540               0.001544 -0.003211
# Bottle Volume (ml)                 0.159434               0.159243  0.083508
# State Bottle Cost                  0.008386               0.008352  0.144026
# State Bottle Retail                0.008741               0.008707  0.144205
# Bottles Sold                       0.905197               0.905233  0.840511
# Sale (Dollars)                     0.862246               0.862262  0.999845
# Volume Sold (Liters)               1.000000               1.000000  0.864882
# Volume Sold (Gallons)              1.000000               1.000000  0.864897
# Margin                             0.864882               0.864897  1.000000
# Price per Liter                   -0.096946              -0.096873  0.065455
#
#                        Price per Liter
# Store Number                 -0.016145
# Category                     -0.003992
# Vendor Number                 0.003605
# Bottle Volume (ml)           -0.315272
# State Bottle Cost             0.720462
# State Bottle Retail           0.720010
# Bottles Sold                 -0.065646
# Sale (Dollars)                0.066216
# Volume Sold (Liters)         -0.096946
# Volume Sold (Gallons)        -0.096873
# Margin                        0.065455
# Price per Liter               1.000000

# %% [markdown]
# ### Validate findings using statistical analysis (p-values, confidence intervals) as applicable (possibly use statsmodels, scipy, numpy, scikit learn)

# %%
new_sample.describe()
# Out:
#        Store Number      Category  Vendor Number  Bottle Volume (ml)  \
# count  26926.000000  2.692600e+04   26926.000000        26926.000000
# mean    3591.643913  1.044156e+06     257.108965          924.699287
# std      948.877904  5.146249e+04     140.467043          495.472421
# min     2106.000000  1.011100e+06      10.000000          100.000000
# 25%     2605.000000  1.012200e+06     115.000000          750.000000
# 50%     3721.000000  1.031200e+06     260.000000          750.000000
# 75%     4392.000000  1.062310e+06     380.000000         1000.000000
# max     9023.000000  1.701100e+06     978.000000         4800.000000
#
#        State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# count       26926.000000         26926.000000  26926.000000    26926.000000
# mean            9.734851            14.617685      9.654757      125.230767
# std             6.789135            10.183027     22.797524      337.719415
# min             0.890000             1.340000      1.000000        1.500000
# 25%             5.510000             8.270000      2.000000       30.000000
# 50%             8.000000            12.140000      6.000000       69.060000
# 75%            11.800000            17.700000     12.000000      135.000000
# max           139.000000           208.500000   1320.000000    16542.000000
#
#        Volume Sold (Liters)  Volume Sold (Gallons)        Margin  \
# count          26926.000000           26926.000000  26926.000000
# mean               8.716631               2.302896     41.855490
# std               25.511101               6.739300    113.029524
# min                0.100000               0.030000      0.000000
# 25%                1.500000               0.400000     10.000000
# 50%                5.250000               1.390000     23.040000
# 75%               10.500000               2.770000     45.000000
# max             1320.000000             348.710000   5514.000000
#
#        Price per Liter
# count     26926.000000
# mean         17.927412
# std          12.549354
# min           2.760000
# 25%           9.800000
# 50%          14.860000
# 75%          22.490000
# max         278.000000

# %%
# tt = (sm-m)/np.sqrt(sv/float(n))  # t-statistic for mean
#pval = stats.t.sf(np.abs(tt), n-1)*2  # two-sided pvalue = Prob(abs(t)>tt)
#print 't-statistic = %6.3f pvalue = %6.4f' % (tt, pval)
#t-statistic =  0.391 pvalue = 0.6955

# %% [markdown]
# # Build your models
#
# Using scikit-learn or statsmodels, build the necessary models for your scenario. Evaluate model fit.

# %%
# load numpy and pandas for data manipulation
# Link: https://www.datarobot.com/blog/ordinary-least-squares-in-python/
# b = (X'X)^-1(X'Y) Note: OLS Regression; see theta function below

import pandas as pd
import numpy as np
from scipy import linalg

# load statsmodels as alias ``sm``
import statsmodels.api as sm
from statsmodels.regression.quantile_regression import QuantReg

# %%
sales.head()
# Out:
#    Store Number         City  2015 Sales  2015 Sales mean  \
# 0          2106  CEDAR FALLS    13719.10       311.797727
# 1          2113       GOWRIE      714.31        59.525833
# 2          2130     WATERLOO    19461.06       512.133158
# 3          2152     ROCKWELL     1273.23       106.102500
# 4          2178       WAUKON     1832.32        87.253333
#
#    Price per Liter mean Zip Code       County  2015 Volume Sold (Liters)  \
# 0             17.116255    50613   Black Hawk                     841.25
# 1             21.144167    50543      Webster                      44.25
# 2             18.515652    50703   Black Hawk                    1060.20
# 3             14.239444    50469  Cerro Gordo                      79.25
# 4             15.532918    52172    Allamakee                     154.86
#
#    2015 Volume Sold (Liters) mean  2015 Margin mean
# 0                       19.119318        104.096818
# 1                        3.687500         19.844167
# 2                       27.900000        170.772632
# 3                        6.604167         35.420833
# 4                        7.374286         29.391429

# %%
y = sales['2015 Volume Sold (Liters) mean']

# %%
X = sales['2015 Margin mean']

# %%
X = sm.add_constant(X)  # Adds a constant term to the predictor
X.head()
# Out:
#    const  2015 Margin mean
# 0    1.0        104.096818
# 1    1.0         19.844167
# 2    1.0        170.772632
# 3    1.0         35.420833
# 4    1.0         29.391429

# %% [markdown]
# ### Complete linear regressions using scikit-learn or statsmodels and interpret your findings

# %%
theta = linalg.inv(X.T.dot(X)).dot(X.T).dot(y) # X.T: Transpose of the matrix (i.e. 3x2 Matrix
# becomes 2x3 Matrix)
# For the Matrix to be inverted it has to be squared (i.e. 3x2 multiplied by 2x3 is a 3x3 or a
# square matrix)
theta
# Out:
# array([ 1.74576796,  0.17089438])

# %%
est = sm.OLS(y, X)
est = est.fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     2015 Volume Sold (Liters) mean   R-squared:                       0.759
# Model:                                        OLS   Adj. R-squared:                  0.759
# Method:                             Least Squares   F-statistic:                     4091.
# Date:                            Tue, 28 Jun 2016   Prob (F-statistic):               0.00
# Time:                                    20:44:36   Log-Likelihood:                -3710.3
# No. Observations:                            1300   AIC:                             7425.
# Df Residuals:                                1298   BIC:                             7435.
# Df Model:                                       1
# Covariance Type:                        nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# const                1.7458      0.158     11.059      0.000         1.436     2.055
# 2015 Margin mean     0.1709      0.003     63.959      0.000         0.166     0.176
# ==============================================================================
# Omnibus:                      911.982   Durbin-Watson:                   1.829
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           187671.106
# Skew:                           2.216   Prob(JB):                         0.00
# Kurtosis:                      61.695   Cond. No.                         80.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
est.predict(X)
# Out:
# array([ 19.5353287 ,   5.13702443,  30.92985018, ...,  34.07043908,
#         52.30145106,  48.39993247])

# %%
est.params
# Out:
# const               1.745768
# 2015 Margin mean    0.170894
# dtype: float64

# %%
sns.lmplot(x='2015 Margin mean', y='2015 Volume Sold (Liters) mean', data=sales, size = 20)

# %% [markdown]
# ### Calculate and plot predicted probabilities and/or present tables of results

# %%
xs = sales['2015 Margin mean']
ys = [x for x in xs] # true values
predictions = [2*x for x in xs]
print ys
print predictions
# Out:
# [104.09681818181819, 19.84416666666667, 170.77263157894737, 35.420833333333334, 29.391428571428555, 32.422097902097924, 65.583999999999989, 29.584736842105265, 33.766216216216222, 23.972941176470592, 55.303599999999996, 48.795999999999992, 37.49607142857144, 51.440882352941173, 23.729036144578313, 16.314999999999994, 69.278974358974367, 40.987499999999997, 64.22526315789473, 16.281666666666666, 15.863829787234041, 16.992222222222225, 57.290555555555557, 20.077804878048781, 30.512727272727275, 47.408000000000001, 14.030454545454546, 9.9199999999999999, 28.507460317460318, 40.90623076923076, 54.042875000000002, 38.555471698113216, 50.976923076923093, 34.681249999999999, 34.936507936507937, 55.017407407407418, 164.168115942029, 27.539999999999999, 20.48590909090909, 28.95860655737706, 29.066179775280908, 34.417857142857144, 36.871604938271602, 53.112941176470592, 29.214545454545451, 78.834285714285727, 43.385925925925932, 80.177096774193544, 25.15519230769231, 46.613243243243247, 75.969230769230776, 43.595098039215685, 24.147605633802819, 47.057105263157887, 19.811896551724136, 41.915609756097567, 31.965063291139227, 41.847093023255816, 45.542926829268296, 14.499999999999996, 34.411724137931039, 26.423939393939396, 34.592400000000005, 36.135000000000005, 45.338124999999991, 19.490833333333331, 50.320769230769237, 41.811538461538468, 69.325542168674701, 37.722912621359235, 36.235555555555557, 62.491379310344819, 24.717425742574253, 26.831750000000007, 28.846849315068489, 35.44874999999999, 22.843285714285713, 51.824062499999997, 39.28664000000002, 48.292023809523805, 24.65519999999999, 19.265750000000001, 69.228749999999991, 43.098285714285709, 26.458333333333339, 31.697843137254896, 30.917547169811318, 18.365083333333327, 42.169130434782602, 36.285267857142863, 33.974782608695655, 18.625, 69.883877551020404, 25.476493506493515, 41.255322580645135, 16.009999999999998, 40.731666666666662, 68.160000000000011, 23.756451612903223, 38.272926829268286, 30.685813953488378, 33.375346534653467, 43.00264150943395, 37.757540983606567, 63.258695652173913, 75.913181818181826, 21.655000000000001, 46.948536585365851, 22.086296296296297, 33.397397260273962, 60.109239130434787, 42.911775700934577, 27.01321428571428, 29.946333333333332, 19.957734375000001, 50.532833333333329, 101.98019999999997, 25.790254237288138, 44.776666666666671, 49.574705882352937, 33.157887323943669, 46.90937499999999, 45.555000000000007, 46.605392156862756, 44.339473684210532, 161.84947368421058, 36.859384615384613, 50.541621621621623, 38.427384615384611, 27.06583333333333, 39.641599999999997, 31.707027027027028, 59.695072463768113, 39.35760330578514, 41.453576642335754, 23.474499999999999, 24.536749999999994, 30.596785714285716, 35.323333333333323, 24.102564102564102, 44.63750000000001, 19.327894736842108, 17.498999999999999, 31.433999999999997, 31.876785714285713, 46.237272727272718, 27.274067796610172, 55.681097560975623, 35.715104166666663, 34.861979166666671, 21.417058823529416, 14.554000000000002, 25.072857142857139, 57.622241379310346, 40.655000000000001, 36.575384615384621, 31.249433962264145, 39.198, 14.346666666666669, 25.975999999999999, 35.751428571428562, 40.140000000000001, 27.063333333333333, 35.931538461538459, 19.042142857142856, 29.235714285714284, 42.134999999999998, 22.372, 20.951250000000002, 34.396666666666668, 12.390000000000002, 29.636249999999997, 26.513333333333332, 28.666666666666668, 27.92428571428572, 10.852, 20.849999999999994, 40.416428571428582, 24.13666666666667, 40.604999999999997, 26.279999999999998, 24.467777777777776, 13.520000000000003, 14.75, 14.251999999999999, 24.584705882352939, 18.440000000000001, 31.959166666666665, 23.201111111111114, 22.265882352941176, 24.814285714285713, 24.551052631578944, 204.204375, 287.66644067796608, 47.707625000000007, 25.079999999999998, 51.860000000000007, 12.185, 27.501428571428573, 303.94857142857154, 41.658749999999998, 18.910000000000004, 36.928571428571431, 274.61571428571432, 60.119999999999997,  ...
# [208.19363636363639, 39.68833333333334, 341.54526315789474, 70.841666666666669, 58.782857142857111, 64.844195804195849, 131.16799999999998, 59.16947368421053, 67.532432432432444, 47.945882352941183, 110.60719999999999, 97.591999999999985, 74.992142857142881, 102.88176470588235, 47.458072289156625, 32.629999999999988, 138.55794871794873, 81.974999999999994, 128.45052631578946, 32.563333333333333, 31.727659574468081, 33.984444444444449, 114.58111111111111, 40.155609756097562, 61.025454545454551, 94.816000000000003, 28.060909090909092, 19.84, 57.014920634920635, 81.81246153846152, 108.08575, 77.110943396226432, 101.95384615384619, 69.362499999999997, 69.873015873015873, 110.03481481481484, 328.33623188405801, 55.079999999999998, 40.971818181818179, 57.917213114754119, 58.132359550561816, 68.835714285714289, 73.743209876543204, 106.22588235294118, 58.429090909090903, 157.66857142857145, 86.771851851851864, 160.35419354838709, 50.310384615384621, 93.226486486486493, 151.93846153846155, 87.19019607843137, 48.295211267605637, 94.114210526315773, 39.623793103448271, 83.831219512195133, 63.930126582278454, 83.694186046511632, 91.085853658536593, 28.999999999999993, 68.823448275862077, 52.847878787878791, 69.18480000000001, 72.27000000000001, 90.676249999999982, 38.981666666666662, 100.64153846153847, 83.623076923076937, 138.6510843373494, 75.44582524271847, 72.471111111111114, 124.98275862068964, 49.434851485148506, 53.663500000000013, 57.693698630136979, 70.89749999999998, 45.686571428571426, 103.64812499999999, 78.57328000000004, 96.58404761904761, 49.31039999999998, 38.531500000000001, 138.45749999999998, 86.196571428571417, 52.916666666666679, 63.395686274509792, 61.835094339622636, 36.730166666666655, 84.338260869565204, 72.570535714285725, 67.94956521739131, 37.25, 139.76775510204081, 50.95298701298703, 82.51064516129027, 32.019999999999996, 81.463333333333324, 136.32000000000002, 47.512903225806447, 76.545853658536572, 61.371627906976755, 66.750693069306934, 86.0052830188679, 75.515081967213135, 126.51739130434783, 151.82636363636365, 43.310000000000002, 93.897073170731701, 44.172592592592594, 66.794794520547924, 120.21847826086957, 85.823551401869153, 54.026428571428561, 59.892666666666663, 39.915468750000002, 101.06566666666666, 203.96039999999994, 51.580508474576277, 89.553333333333342, 99.149411764705874, 66.315774647887338, 93.81874999999998, 91.110000000000014, 93.210784313725512, 88.678947368421063, 323.69894736842116, 73.718769230769226, 101.08324324324325, 76.854769230769222, 54.131666666666661, 79.283199999999994, 63.414054054054056, 119.39014492753623, 78.715206611570281, 82.907153284671509, 46.948999999999998, 49.073499999999989, 61.193571428571431, 70.646666666666647, 48.205128205128204, 89.27500000000002, 38.655789473684216, 34.997999999999998, 62.867999999999995, 63.753571428571426, 92.474545454545435, 54.548135593220344, 111.36219512195125, 71.430208333333326, 69.723958333333343, 42.834117647058832, 29.108000000000004, 50.145714285714277, 115.24448275862069, 81.310000000000002, 73.150769230769242, 62.498867924528291, 78.396000000000001, 28.693333333333339, 51.951999999999998, 71.502857142857124, 80.280000000000001, 54.126666666666665, 71.863076923076918, 38.084285714285713, 58.471428571428568, 84.269999999999996, 44.744, 41.902500000000003, 68.793333333333337, 24.780000000000005, 59.272499999999994, 53.026666666666664, 57.333333333333336, 55.848571428571439, 21.704000000000001, 41.699999999999989, 80.832857142857165, 48.273333333333341, 81.209999999999994, 52.559999999999995, 48.935555555555553, 27.040000000000006, 29.5, 28.503999999999998, 49.169411764705877, 36.880000000000003, 63.918333333333329, 46.402222222222228, 44.531764705882352, 49.628571428571426, 49.102105263157888, 408.40875, 575.33288135593216, 95.415250000000015, 50.159999999999997, 103.72000000000001, 24.370000000000001, 55.002857142857145, 607.89714285714308, 83.317499999999995, 37.820000000000007, 73.857142857142861, 549.23142857142864, 120.2399 ...

# %% [markdown]
# ### Describe the bias-variance tradeoff of your model and errors metrics

# %% [markdown]
# ### Evaluate model fit by using loss functions, including mean absolute error, mean squared error, and root mean squared error, or r-squared

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
print "RMSE:", mean_squared_error(ys, predictions)
print "MAE:", mean_absolute_error(ys, predictions)
# Out:
# RMSE: 3490.31644401
# MAE: 39.8312667553

# %% [markdown]
# ## Plot your results
#
# Again make sure that you record any valuable information. For example, in the tax scenario, did you find the sales from the first three months of the year to be a good predictor of the total sales for the year? Plot the predictions versus the true values and discuss the successes and limitations of your models

# %% [markdown]
# # Present the Results
#
# Present your conclusions and results. If you have more than one interesting model feel free to include more than one along with a discussion. Use your work in this notebook to prepare your write-up.

# %% [markdown]
# ### Create a Jupyter writeup hosted on GitHub that provides a dataset overview with visualizations, statistical analysis, data cleaning methodologies, and models

# %% [markdown]
# For this dataset my task was to recommend to a particular investor some locations in Iowa that would be ideal for opening up a liquor store. I used various cleaning methods and visualizations in order to understand the data and make it usable. For cleaning, I converted the "Date" column to datetime, removed any $ signs with the regex function, and changed numerical columns from object to float data types. For visualizations, I used matplotlib to plot scatter plots of numerical columns vs. Sale (Dollars). I also plotted county, city, and zip code by Sale (Dollars) to understand what areas had the best sales. I created a linear regression of the 2015 Margin Mean vs 2015 Volume Sold (Liters) mean and as expected it had a positive correlation. This showed that as the average volume sold increased so did the margin.

# %% [markdown]
# ### Create a writeup on the interpretation of findings including an executive summary with conclusions and next steps

# %% [markdown]
# # Bonus!

# %% [markdown]
# ### Handle outliers, use regularization (Ridge & Lasso regressions)

# %% [markdown]
# ### Brainstorm ways to improve your analysis; for example:
# #### Add additional breakdowns and models, e.g. by month.
# #### Recommend additional data that might improve your models
# #### Can you think of other uses for the dataset? E.g healthcare / disease estimates

# %% [markdown]
# ### Create a blog post of at least 500 words (and 1-2 graphics!) describing your data, analysis, and approach. Link to it in your Jupyter notebook.
